# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Library
#
# https://github.com/mhardalov/exams-qa

# %%
pip install torch==1.9.0+cu111 torchvision==0.10.0+cu111 torchaudio==0.9.0 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# Collecting torch==1.9.0+cu111
#   Downloading https://download.pytorch.org/whl/cu111/torch-1.9.0%2Bcu111-cp38-cp38-linux_x86_64.whl (2041.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 GB 861.0 kB/s eta 0:00:00
# Collecting torchvision==0.10.0+cu111
#   Downloading https://download.pytorch.org/whl/cu111/torchvision-0.10.0%2Bcu111-cp38-cp38-linux_x86_64.whl (23.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.2/23.2 MB 70.0 MB/s eta 0:00:00
# Collecting torchaudio==0.9.0
#   Downloading torchaudio-0.9.0-cp38-cp38-manylinux1_x86_64.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 61.8 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch==1.9.0+cu111) (4.5.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from torchvision==0.10.0+cu111) (1.22.4)
# Requirement already satisfied: pillow>=5.3.0 in /usr/local/lib/python3.8/dist-packages (from torchvision==0.10.0+cu111) (7.1.2)
# Installing collected packages: torch, torchvision, torchaudio
#   Attempting uninstall: torch
#     Found existing installation: torch 1.13.1+cu116
#     Uninstalling torch-1.13.1+cu116:
#       Successfully uninstalled torch-1.13.1+cu116
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.14.1+cu116
#     Uninstalling torchvision-0.14.1+cu116:
#       Successfully uninstalled torchvision-0.14.1+cu116
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 0.13.1+cu116
#     Uninstalling torchaudio-0.13.1+cu116:
#       Successfully uninstalled torchaudio-0.13.1+cu116
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.14.1 requires torch==1.13.1, but you have torch 1.9.0+cu111 which is incompatible.
# Successfully installed torch-1.9.0+cu111 torchaudio-0.9.0 torchvision-0.10.0+cu111

# %%
# !pip install transformers==2.8.0
# !pip install transformers==3.0.2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers==3.0.2
#   Downloading transformers-3.0.2-py3-none-any.whl (769 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 769.0/769.0 KB 888.0 kB/s eta 0:00:00
# Collecting tokenizers==0.8.1.rc1
#   Downloading tokenizers-0.8.1rc1-cp38-cp38-manylinux1_x86_64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 83.2 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.8/dist-packages (from transformers==3.0.2) (4.64.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from transformers==3.0.2) (23.0)
# Collecting sacremoses
#   Downloading sacremoses-0.0.53.tar.gz (880 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 880.6/880.6 KB 61.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from transformers==3.0.2) (1.22.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers==3.0.2) (2022.6.2)
# Collecting sentencepiece!=0.1.92
#   Downloading sentencepiece-0.1.97-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 73.1 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers==3.0.2) (3.9.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from transformers==3.0.2) (2.25.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->transformers==3.0.2) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->transformers==3.0.2) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->transformers==3.0.2) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->transformers==3.0.2) (1.24.3)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from sacremoses->transformers==3.0.2) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from sacremoses->transformers==3.0.2) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from sacremoses->transformers==3.0.2) (1.2.0)
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895260 sha256=e824eef82d3b1df58440e77867a338e2a2ecc6a4e85db3022db8fc060a1bbadc
#   Stored in directory: /root/.cache/pip/wheels/82/ab/9b/c15899bf659ba74f623ac776e861cf2eb8608c1825ddec66a4
# Successfully built sacremoses
# Installing collected packages: tokenizers, sentencepiece, sacremoses, transformers
# Successfully installed sacremoses-0.0.53 sentencepiece-0.1.97 tokenizers-0.8.1rc1 transformers-3.0.2

# %%
pip install tqdm==4.50.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tqdm==4.50.0
#   Downloading tqdm-4.50.0-py2.py3-none-any.whl (70 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.7/70.7 KB 8.4 MB/s eta 0:00:00
# Installing collected packages: tqdm
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.64.1
#     Uninstalling tqdm-4.64.1:
#       Successfully uninstalled tqdm-4.64.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.14.1 requires torch==1.13.1, but you have torch 1.9.0+cu111 which is incompatible.
# Successfully installed tqdm-4.50.0

# %%
pip install  --upgrade  git+https://github.com/lanpa/tensorboardX.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/lanpa/tensorboardX.git
#   Cloning https://github.com/lanpa/tensorboardX.git to /tmp/pip-req-build-9nsvwqrn
#   Running command git clone --filter=blob:none --quiet https://github.com/lanpa/tensorboardX.git /tmp/pip-req-build-9nsvwqrn
#   Resolved https://github.com/lanpa/tensorboardX.git to commit ceabb20143e99436a7622520c58641f82eb1d3ca
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from tensorboardX===v2.5.1-14-gceabb20-ceabb20) (1.22.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from tensorboardX===v2.5.1-14-gceabb20-ceabb20) (23.0)
# Requirement already satisfied: protobuf<4,>=3.8.0 in /usr/local/lib/python3.8/dist-packages (from tensorboardX===v2.5.1-14-gceabb20-ceabb20) (3.19.6)
# Building wheels for collected packages: tensorboardX
#   Building wheel for tensorboardX (setup.py) ... done
#   Created wheel for tensorboardX: filename=tensorboardX-v2.5.1_14_gceabb20-py2.py3-none-any.whl size=114654 sha256=e12cd67d62e1cf3e0d4ccf50650f58ac598dd40995f5625f88a4f42f35d666fc
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ruyhgv9n/wheels/12/5f/44/eea2cfeebe3401dbe0725409cea3d9823052f4292428a8c8d1
#   WARNING: Built wheel for tensorboardX is invalid: Metadata 1.2 mandates PEP 440 version, but 'v2.5.1-14-gceabb20' is not
# Failed to build tensorboardX
# Installing collected packages: tensorboardX
#   Running setup.py install for tensorboardX ... done
#   DEPRECATION: tensorboardX was installed using the legacy 'setup.py install' method, because a wheel could not be built for it. A possible replacement is to fix the wheel build issue reported above. Discussion can be found at https://github.com/pypa/pip/issues/8368
# Successfully installed tensorboardX-v2.5.1-14-gceabb20-ceabb20

# %%
pip install --upgrade git+https://github.com/pytorch/ignite.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/pytorch/ignite.git
#   Cloning https://github.com/pytorch/ignite.git to /tmp/pip-req-build-1x_ob6_o
#   Running command git clone --filter=blob:none --quiet https://github.com/pytorch/ignite.git /tmp/pip-req-build-1x_ob6_o
#   Resolved https://github.com/pytorch/ignite.git to commit 52446b33bac9d334cd232c866b6013e09c24b161
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: torch<3,>=1.3 in /usr/local/lib/python3.8/dist-packages (from pytorch-ignite==0.5.0) (1.9.0+cu111)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from pytorch-ignite==0.5.0) (23.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch<3,>=1.3->pytorch-ignite==0.5.0) (4.5.0)
# Building wheels for collected packages: pytorch-ignite
#   Building wheel for pytorch-ignite (pyproject.toml) ... done
#   Created wheel for pytorch-ignite: filename=pytorch_ignite-0.5.0-py3-none-any.whl size=264269 sha256=eacc38252fb89f836e5b333e721e4745c4fafc5bace5a9855bb505c001d5f64d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-7nxrl78k/wheels/30/c5/b6/a33c1fa72cf29f2460e45d69552e991bac7b4ad328f832005a
# Successfully built pytorch-ignite
# Installing collected packages: pytorch-ignite
# Successfully installed pytorch-ignite-0.5.0

# %%
pip install jsonlines
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting jsonlines
#   Downloading jsonlines-3.1.0-py3-none-any.whl (8.6 kB)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.8/dist-packages (from jsonlines) (22.2.0)
# Installing collected packages: jsonlines
# Successfully installed jsonlines-3.1.0

# %% [markdown]
# # Models

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import torch
from transformers import BertForMaskedLM, RobertaForMaskedLM, XLMRobertaForMaskedLM, DistilBertForMaskedLM


class BertLMForMultipleChoice(BertForMaskedLM):
    def __init__(self, config):
        super().__init__(config)

        self.init_weights()

    def forward(
        self,
        input_ids=None,
        attention_mask=None,
        token_type_ids=None,
        position_ids=None,
        head_mask=None,
        inputs_embeds=None,
        masked_positions=None,
        masked_input_ids=None,
        labels=None,
    ):
        batch_size, num_choices, num_words = input_ids.shape

        input_ids = input_ids.view(-1, input_ids.size(-1))
        masked_input_ids = input_ids.view(-1, input_ids.size(-1))
        attention_mask = (
            attention_mask.view(-1, attention_mask.size(-1)) if attention_mask is not None else None
        )
        token_type_ids = (
            token_type_ids.view(-1, token_type_ids.size(-1)) if token_type_ids is not None else None
        )
        position_ids = (
            position_ids.view(-1, position_ids.size(-1)) if position_ids is not None else None
        )

        prediction_scores = super().forward(
            masked_input_ids,
            attention_mask=attention_mask,
            # token_type_ids=token_type_ids,
            # position_ids=position_ids,
            head_mask=head_mask,
        )

        predicted_probs = torch.softmax(
            prediction_scores[0].view(batch_size, num_choices, num_words, -1), dim=-1
        ).view(-1, self.config.vocab_size)

        log_probs = torch.log(
            predicted_probs.gather(-1, input_ids.view(-1, 1)).view(
                batch_size, num_choices, num_words
            )
        ).masked_fill(masked_positions == 0, 0)

        scores = 1 / (-log_probs.sum(dim=-1) / masked_positions.sum(axis=-1))

        return torch.FloatTensor(0), scores


class RobertaLMForMultipleChoice(RobertaForMaskedLM):
    def __init__(self, config):
        super().__init__(config)

        self.init_weights()

    def forward(
        self,
        input_ids=None,
        attention_mask=None,
        token_type_ids=None,
        position_ids=None,
        head_mask=None,
        inputs_embeds=None,
        masked_positions=None,
        masked_input_ids=None,
        labels=None,
    ):
        batch_size, num_choices, num_words = input_ids.shape

        input_ids = input_ids.view(-1, input_ids.size(-1))
        masked_input_ids = input_ids.view(-1, input_ids.size(-1))
        attention_mask = (
            attention_mask.view(-1, attention_mask.size(-1)) if attention_mask is not None else None
        )
        token_type_ids = (
            token_type_ids.view(-1, token_type_ids.size(-1)) if token_type_ids is not None else None
        )
        position_ids = (
            position_ids.view(-1, position_ids.size(-1)) if position_ids is not None else None
        )

        prediction_scores = super().forward(
            masked_input_ids,
            attention_mask=attention_mask,
            token_type_ids=token_type_ids,
            position_ids=position_ids,
            head_mask=head_mask,
        )

        predicted_probs = torch.softmax(
            prediction_scores[0].view(batch_size, num_choices, num_words, -1), dim=-1
        ).view(-1, self.config.vocab_size)

        log_probs = torch.log(
            predicted_probs.gather(-1, input_ids.view(-1, 1)).view(
                batch_size, num_choices, num_words
            )
        ).masked_fill(masked_positions == 0, 0)

        scores = 1 / (-log_probs.sum(dim=-1) / masked_positions.sum(axis=-1))

        return torch.FloatTensor(0), scores


class XLMRobertaLMForMultipleChoice(XLMRobertaForMaskedLM):
    def __init__(self, config):
        super().__init__(config)

        self.init_weights()

    def forward(
        self,
        input_ids=None,
        attention_mask=None,
        token_type_ids=None,
        position_ids=None,
        head_mask=None,
        inputs_embeds=None,
        masked_positions=None,
        masked_input_ids=None,
        labels=None,
    ):
        batch_size, num_choices, num_words = input_ids.shape

        input_ids = input_ids.view(-1, input_ids.size(-1))
        masked_input_ids = input_ids.view(-1, input_ids.size(-1))
        attention_mask = (
            attention_mask.view(-1, attention_mask.size(-1)) if attention_mask is not None else None
        )
        token_type_ids = (
            token_type_ids.view(-1, token_type_ids.size(-1)) if token_type_ids is not None else None
        )
        position_ids = (
            position_ids.view(-1, position_ids.size(-1)) if position_ids is not None else None
        )

        prediction_scores = super().forward(
            masked_input_ids,
            attention_mask=attention_mask,
            token_type_ids=token_type_ids,
            position_ids=position_ids,
            head_mask=head_mask,
        )

        predicted_probs = torch.softmax(
            prediction_scores[0].view(batch_size, num_choices, num_words, -1), dim=-1
        ).view(-1, self.config.vocab_size)

        log_probs = torch.log(
            predicted_probs.gather(-1, input_ids.view(-1, 1)).view(
                batch_size, num_choices, num_words
            )
        ).masked_fill(masked_positions == 0, 0)

        scores = 1 / (-log_probs.sum(dim=-1) / masked_positions.sum(axis=-1))

        return torch.FloatTensor(0), scores

class DistilBertLMForMultipleChoice(DistilBertForMaskedLM):
    def __init__(self, config):
        super().__init__(config)

        self.init_weights()

    def forward(
        self,
        input_ids=None,
        attention_mask=None,
        token_type_ids=None,
        position_ids=None,
        head_mask=None,
        inputs_embeds=None,
        masked_positions=None,
        masked_input_ids=None,
        labels=None,
    ):
        batch_size, num_choices, num_words = input_ids.shape

        input_ids = input_ids.view(-1, input_ids.size(-1))
        masked_input_ids = input_ids.view(-1, input_ids.size(-1))
        attention_mask = (
            attention_mask.view(-1, attention_mask.size(-1)) if attention_mask is not None else None
        )
        token_type_ids = (
            token_type_ids.view(-1, token_type_ids.size(-1)) if token_type_ids is not None else None
        )
        position_ids = (
            position_ids.view(-1, position_ids.size(-1)) if position_ids is not None else None
        )

        prediction_scores = super().forward(
            masked_input_ids,
            # attention_mask=attention_mask,
            # token_type_ids=token_type_ids,
            # position_ids=position_ids,
            head_mask=head_mask,
        )

        predicted_probs = torch.softmax(
            prediction_scores[0].view(batch_size, num_choices, num_words, -1), dim=-1
        ).view(-1, self.config.vocab_size)

        log_probs = torch.log(
            predicted_probs.gather(-1, input_ids.view(-1, 1)).view(
                batch_size, num_choices, num_words
            )
        ).masked_fill(masked_positions == 0, 0)

        scores = 1 / (-log_probs.sum(dim=-1) / masked_positions.sum(axis=-1))

        return torch.FloatTensor(0), scores

# %% [markdown]
# # Utils

# %%
import csv
import glob
import json
import logging
import os
from typing import List

import numpy as np
from tqdm import tqdm
from transformers import PreTrainedTokenizer

logger = logging.getLogger(__name__)


class InputExample(object):
    """A single training/test example for multiple choice"""

    def __init__(self, example_id, question, contexts, endings, label=None):
        """Constructs a InputExample.
        Args:
            example_id: Unique id for the example.
            contexts: list of str. The untokenized text of the first sequence (context of corresponding question).
            question: string. The untokenized text of the second sequence (question).
            endings: list of str. multiple choice's options. Its length must be equal to contexts' length.
            label: (Optional) string. The label of the example. This should be
            specified for train and dev examples, but not for test examples.
        """
        self.example_id = example_id
        self.question = question
        self.contexts = contexts
        self.endings = endings
        self.label = label


class InputExampleEXAMS(InputExample):
    """A single training/test example for multiple choice"""

    def __init__(self, example_id, question, contexts, endings, options_size, label=None):
        super(InputExampleEXAMS, self).__init__(example_id, question, contexts, endings, label)
        self.options_size = options_size


class InputFeatures(object):
    def __init__(self, example_id, choices_features, answers_mask, label):
        self.example_id = example_id
        self.choices_features = [
            {"input_ids": input_ids, "input_mask": input_mask, "segment_ids": segment_ids}
            for input_ids, input_mask, segment_ids in choices_features
        ]
        self.answers_mask = answers_mask
        self.label = label


class DataProcessor(object):
    """Base class for data converters for multiple choice data sets."""

    def get_train_examples(self, data_dir):
        """Gets a collection of `InputExample`s for the train set."""
        raise NotImplementedError()

    def get_dev_examples(self, data_dir):
        """Gets a collection of `InputExample`s for the dev set."""
        raise NotImplementedError()

    def get_test_examples(self, data_dir):
        """Gets a collection of `InputExample`s for the test set."""
        raise NotImplementedError()

    def get_labels(self):
        """Gets the list of labels for this data set."""
        raise NotImplementedError()


class RaceProcessor(DataProcessor):
    """Processor for the RACE data set."""

    def get_train_examples(self, data_dir):
        """See base class."""
        logger.info("LOOKING AT {} train".format(data_dir))
        high = os.path.join(data_dir, "train_race.json")
        # middle = os.path.join(data_dir, "train/middle")
        high = self._read_txt(high)
        # middle = self._read_txt(middle)
        return self._create_examples(high, "train")

    def get_dev_examples(self, data_dir):
        """See base class."""
        logger.info("LOOKING AT {} dev".format(data_dir))
        high = os.path.join(data_dir, "dev_race.json")
        # middle = os.path.join(data_dir, "dev/middle")
        high = self._read_txt(high)
        # middle = self._read_txt(middle)
        return self._create_examples(high, "dev")

    def get_test_examples(self, data_dir):
        """See base class."""
        logger.info("LOOKING AT {} test".format(data_dir))
        high = os.path.join(data_dir, "test_race.json")
        # middle = os.path.join(data_dir, "test/middle")
        high = self._read_txt(high)
        # middle = self._read_txt(middle)
        return self._create_examples(high, "test")

    def get_labels(self):
        """See base class."""
        return ["0", "1", "2", "3"]

    def _read_txt(self, input_dir):
        lines = []
        # files = glob.glob(input_dir + "/*json")
        # for file in tqdm(files, desc="read files", disable = True):
        #     with open(file, "r", encoding="utf-8") as fin:
        #         data_raw = json.load(fin)
        #         data_raw["race_id"] = file
        #         lines.append(data_raw)
        with open(input_dir, "r", encoding="utf-8") as fin:
            data_raw = json.load(fin)
        for d in data_raw:
            d['race_id'] = d['files']
            lines.append(d)
        return lines

    def _create_examples(self, lines, set_type):
        """Creates examples for the training and dev sets."""
        examples = []
        for (_, data_raw) in enumerate(lines):
            race_id = "%s-%s" % (set_type, data_raw["race_id"])
            article = data_raw["article"]
            for i in range(len(data_raw["answers"])):
                truth = str(ord(data_raw["answers"][i]) - ord("A"))
                # try:
                #     truth = str(ord(data_raw["answers"][i]) - ord("A"))
                # except Exception as e:
                #     print(data_raw["answers"][i])
                #     print("-----")
                #     print(data_raw["answers"])
                #     raise e
                question = data_raw["questions"][i]
                options = data_raw["options"][i]

                examples.append(
                    InputExample(
                        example_id=race_id,
                        question=question,
                        contexts=[
                            article,
                            article,
                            article,
                            article,
                        ],  # this is not efficient but convenient
                        endings=[options[0], options[1], options[2], options[3]],
                        label=truth,
                    )
                )
        return examples


class SwagProcessor(DataProcessor):
    """Processor for the SWAG data set."""

    def get_train_examples(self, data_dir):
        """See base class."""
        logger.info("LOOKING AT {} train".format(data_dir))
        return self._create_examples(self._read_csv(os.path.join(data_dir, "train.csv")), "train")

    def get_dev_examples(self, data_dir):
        """See base class."""
        logger.info("LOOKING AT {} dev".format(data_dir))
        return self._create_examples(self._read_csv(os.path.join(data_dir, "val.csv")), "dev")

    def get_test_examples(self, data_dir):
        """See base class."""
        logger.info("LOOKING AT {} dev".format(data_dir))
        raise ValueError(
            "For swag testing, the input file does not contain a label column. It can not be tested in current code"
            "setting!"
        )
        return self._create_examples(self._read_csv(os.path.join(data_dir, "test.csv")), "test")

    def get_labels(self):
        """See base class."""
        return ["0", "1", "2", "3"]

    def _read_csv(self, input_file):
        with open(input_file, "r", encoding="utf-8") as f:
            return list(csv.reader(f))

    def _create_examples(self, lines: List[List[str]], type: str):
        """Creates examples for the training and dev sets."""
        if type == "train" and lines[0][-1] != "label":
            raise ValueError("For training, the input file must contain a label column.")

        examples = [
            InputExample(
                example_id=line[2],
                question=line[5],  # in the swag dataset, the
                # common beginning of each
                # choice is stored in "sent2".
                contexts=[line[4], line[4], line[4], line[4]],
                endings=[line[7], line[8], line[9], line[10]],
                label=line[11],
            )
            for line in lines[1:]  # we skip the line with the column names
        ]

        return examples


class ArcProcessor(DataProcessor):
    """Processor for the ARC data set (request from allennlp)."""

    def __init__(self, para_type="per_choice"):
        self.para_type = para_type

    def get_train_examples(self, data_dir):
        """See base class."""
        logger.info("LOOKING AT {} train".format(data_dir))
        return self._create_examples(
            self._read_json(os.path.join(data_dir, "train.jsonl")),
            "train",
            para_type=self.para_type,
        )

    def get_dev_examples(self, data_dir):
        """See base class."""
        logger.info("LOOKING AT {} dev".format(data_dir))
        return self._create_examples(
            self._read_json(os.path.join(data_dir, "dev.jsonl")), "dev", para_type=self.para_type
        )

    def get_test_examples(self, data_dir):
        logger.info("LOOKING AT {} test".format(data_dir))
        return self._create_examples(
            self._read_json(os.path.join(data_dir, "test.jsonl")), "test", para_type=self.para_type
        )

    def get_labels(self):
        """See base class."""
        return ["0", "1", "2", "3"]

    def _read_json(self, input_file):
        with open(input_file, "r", encoding="utf-8") as fin:
            lines = fin.readlines()
            return lines

    def _create_examples(self, lines, type, para_type="per_choice"):
        """Creates examples for the training and dev sets."""

        def get_contexts(data_raw, para_type):
            contexts = []
            if para_type == "per_choice":
                for option in data_raw["question"]["choices"]:
                    para_context = ""
                    if "para" in option:
                        para_context = option["para"].replace("_", "")
                    else:
                        para_context = data_raw["para"].replace("_", "")
                    contexts.append(para_context)
            elif para_type == "concat_choices":
                para_context = " ".join(
                    [ch["text"].strip() for ch in data_raw["question"]["choices"]]
                )
                for oi in range(len(data_raw["question"]["choices"])):
                    contexts.append(para_context)
            else:
                raise Exception('para_type "{0}" is not supported!'.format(para_type))

            return contexts

        # There are two types of labels. They should be normalized
        def normalize(truth):
            if truth in "ABCD":
                return ord(truth) - ord("A")
            elif truth in "1234":
                return int(truth) - 1
            else:
                logger.info("truth ERROR! %s", str(truth))
                return None

        examples = []
        three_choice = 0
        four_choice = 0
        five_choice = 0
        other_choices = 0
        # we deleted example which has more than or less than four choices
        for line in tqdm(lines, desc="read arc data"):
            data_raw = json.loads(line.strip("\n"))
            if len(data_raw["question"]["choices"]) == 3:
                three_choice += 1
                continue
            elif len(data_raw["question"]["choices"]) == 5:
                five_choice += 1
                continue
            elif len(data_raw["question"]["choices"]) != 4:
                other_choices += 1
                continue
            four_choice += 1
            truth = str(normalize(data_raw["answerKey"]))
            assert truth != "None"
            question_choices = data_raw["question"]
            question = question_choices["stem"]
            id = data_raw["id"]
            options = question_choices["choices"]
            if len(options) == 4:
                contexts = get_contexts(data_raw, para_type)
                examples.append(
                    InputExample(
                        example_id=id,
                        question=question,
                        contexts=contexts,
                        endings=[
                            options[0]["text"],
                            options[1]["text"],
                            options[2]["text"],
                            options[3]["text"],
                        ],
                        label=truth,
                    )
                )

        if type == "train":
            assert len(examples) > 1
            assert examples[0].label is not None

        logger.info("len examples: %s}", str(len(examples)))
        logger.info("Three choices: %s", str(three_choice))
        logger.info("Five choices: %s", str(five_choice))
        logger.info("Other choices: %s", str(other_choices))
        logger.info("four choices: %s", str(four_choice))

        return examples


class ExamsProcessor(ArcProcessor):
    def get_labels(self):
        """See base class."""
        return ["0", "1", "2", "3", "4", "5"]

    def _create_examples(self, lines, type, para_type="per_choice"):
        """Creates examples for the training and dev sets."""

        def get_contexts(data_raw, para_type):
            contexts = []
            if para_type == "per_choice":
                for option in data_raw["question"]["choices"]:
                    if "para" in option:
                        para_context = option["para"].replace("_", "")
                    else:
                        para_context = data_raw["para"].replace("_", "")
                    contexts.append(para_context)
            elif para_type == "concat_choices":
                para_context = " ".join(
                    [ch["text"].strip() for ch in data_raw["question"]["choices"]]
                )
                for oi in range(len(data_raw["question"]["choices"])):
                    contexts.append(para_context)
            elif para_type == "ignore":
                contexts += [""] * len(data_raw["question"]["choices"])
            else:
                raise Exception('para_type "{0}" is not supported!'.format(para_type))

            return contexts

        # There are two types of labels. They should be normalized
        def normalize(truth):
            if truth in "ABCDE":
                return ord(truth) - ord("A")
            elif truth in "12345":
                return int(truth) - 1
            else:
                logger.info("truth ERROR! %s", str(truth))
                return None

        examples = []
        three_choice = 0
        four_choice = 0
        five_choice = 0
        other_choices = 0
        # we deleted example which has more than or less than four choices
        for line in tqdm(lines, desc="read arc data"):
            data_raw = json.loads(line.strip("\n"))
            if len(data_raw["question"]["choices"]) == 3:
                three_choice += 1
                # continue
            elif len(data_raw["question"]["choices"]) == 5:
                five_choice += 1
                # continue
            elif len(data_raw["question"]["choices"]) == 4:
                four_choice += 1
            else:
                other_choices += 1
                continue

            truth = str(normalize(data_raw["answerKey"]))
            if truth == "None":
                continue

            assert truth != "None"
            question_choices = data_raw["question"]
            question = question_choices["stem"]
            id = data_raw["id"]
            options = question_choices["choices"]

            contexts = get_contexts(data_raw, para_type)
            options_size = len(options)
            if options_size < 5:
                pad_size = 5 - len(options)
                contexts += [""] * pad_size
                options += [{"text": ""}] * pad_size

            examples.append(
                InputExampleEXAMS(
                    example_id=id,
                    question=question,
                    contexts=contexts,
                    endings=[o["text"] for o in options],
                    options_size=options_size,
                    label=truth,
                )
            )

        if type == "train":
            assert len(examples) > 1
            assert examples[0].label is not None

        logger.info("len examples: %s}", str(len(examples)))
        logger.info("Three choices: %s", str(three_choice))
        logger.info("Five choices: %s", str(five_choice))
        logger.info("Other choices: %s", str(other_choices))
        logger.info("four choices: %s", str(four_choice))

        return examples


def convert_examples_to_features(
    examples: List[InputExample],
    label_list: List[str],
    max_length: int,
    tokenizer: PreTrainedTokenizer,
    pad_token_segment_id=0,
    pad_on_left=False,
    pad_token=0,
    mask_padding_with_zero=True,
    kb_masking=False,
) -> List[InputFeatures]:
    """
    Loads a data file into a list of `InputFeatures`
    """

    label_map = {label: i for i, label in enumerate(label_list)}

    features = []
    for (ex_index, example) in tqdm(enumerate(examples), desc="convert examples to features"):
        if ex_index % 10000 == 0:
            logger.info("Writing example %d of %d" % (ex_index, len(examples)))
        choices_features = []
        for ending_idx, (context, ending) in enumerate(zip(example.contexts, example.endings)):
            if not kb_masking:
                text_a = context
                if example.question.find("_") != -1:
                    # this is for cloze question
                    text_b = example.question.replace("_", ending)
                else:
                    text_b = example.question + " " + ending
            else:
                # Hack for RoBERTa, this is a work-around for empty texts.
                text_b = ending if ending != "" else "empty"
                text_a = example.question + " " + context

            inputs = tokenizer.encode_plus(
                text_a,
                text_b,
                add_special_tokens=True,
                max_length=max_length,
                return_token_type_ids=True,
            )
            if "num_truncated_tokens" in inputs and inputs["num_truncated_tokens"] > 0:
                logger.info(
                    "Attention! you are cropping tokens (swag task is ok). "
                    "If you are training ARC and RACE and you are poping question + options,"
                    "you need to try to use a bigger max seq length!"
                )

            input_ids, token_type_ids = inputs["input_ids"], inputs["token_type_ids"]

            # The mask has 1 for real tokens and 0 for padding tokens. Only real
            # tokens are attended to.
            attention_mask = [1 if mask_padding_with_zero else 0] * len(input_ids)

            # Zero-pad up to the sequence length.
            padding_length = max_length - len(input_ids)
            if pad_on_left:
                input_ids = ([pad_token] * padding_length) + input_ids
                attention_mask = (
                    [0 if mask_padding_with_zero else 1] * padding_length
                ) + attention_mask
                token_type_ids = ([pad_token_segment_id] * padding_length) + token_type_ids
            else:
                input_ids = input_ids + ([pad_token] * padding_length)
                attention_mask = attention_mask + (
                    [0 if mask_padding_with_zero else 1] * padding_length
                )
                token_type_ids = token_type_ids + ([pad_token_segment_id] * padding_length)

            assert len(input_ids) == max_length
            assert len(attention_mask) == max_length
            assert len(token_type_ids) == max_length
            choices_features.append((input_ids, attention_mask, token_type_ids))

        label = label_map[example.label]

        if ex_index < 2:
            logger.info("*** Example ***")
            logger.info("race_id: {}".format(example.example_id))
            for choice_idx, (input_ids, attention_mask, token_type_ids) in enumerate(
                choices_features
            ):
                logger.info("choice: {}".format(choice_idx))
                logger.info("input_ids: {}".format(" ".join(map(str, input_ids))))
                logger.info("attention_mask: {}".format(" ".join(map(str, attention_mask))))
                logger.info("token_type_ids: {}".format(" ".join(map(str, token_type_ids))))
                logger.info("label: {}".format(label))

        answers_mask = np.ones(len(choices_features), np.int32)
        if isinstance(example, InputExampleEXAMS):
            answers_mask[example.options_size :] = 0

        features.append(
            InputFeatures(
                example_id=example.example_id,
                choices_features=choices_features,
                answers_mask=answers_mask,
                label=label,
            )
        )

    return features


processors = {
    "race": RaceProcessor,
    "swag": SwagProcessor,
    "arc": ArcProcessor,
    "exams": ExamsProcessor,
}


MULTIPLE_CHOICE_TASKS_NUM_LABELS = {"race", 4, "swag", 4, "arc", 4, "exams", 5}

# %% [markdown]
# # Module

# %%
import argparse
import glob
import json
import logging
import os
import random

import numpy as np
import torch
# from examsqa.models_multiple_choice import (
#     BertLMForMultipleChoice,
#     RobertaLMForMultipleChoice,
#     XLMRobertaLMForMultipleChoice,
# )
from torch.utils.data import DataLoader, RandomSampler, SequentialSampler, TensorDataset
from torch.utils.data.distributed import DistributedSampler
from tqdm import tqdm, trange
from transformers import (
    WEIGHTS_NAME,
    AdamW,
    BertConfig,
    BertForMultipleChoice,
    BertTokenizer,
    RobertaConfig,
    RobertaForMultipleChoice,
    RobertaTokenizer,
    XLMRobertaConfig,
    XLMRobertaForMultipleChoice,
    XLMRobertaTokenizer,
    XLNetConfig,
    XLNetForMultipleChoice,
    XLNetTokenizer,
    get_linear_schedule_with_warmup,
)

from transformers import BERT_PRETRAINED_CONFIG_ARCHIVE_MAP, DISTILBERT_PRETRAINED_CONFIG_ARCHIVE_MAP, XLM_ROBERTA_PRETRAINED_CONFIG_ARCHIVE_MAP

from transformers import DistilBertConfig, DistilBertForMultipleChoice, DistilBertTokenizer

# from utils_multiple_choice import convert_examples_to_features, processors

try:
    from torch.utils.tensorboard import SummaryWriter
except ImportError:
    from tensorboardX import SummaryWriter


logger = logging.getLogger(__name__)

# ALL_MODELS = sum(
#     (
#         tuple(conf.pretrained_config_archive_map.keys())
#         for conf in (BertConfig, XLNetConfig, RobertaConfig)
#     ),
#     (),
# )



ALL_MODELS = tuple(DISTILBERT_PRETRAINED_CONFIG_ARCHIVE_MAP.keys()) + tuple(BERT_PRETRAINED_CONFIG_ARCHIVE_MAP.keys()) + tuple(XLM_ROBERTA_PRETRAINED_CONFIG_ARCHIVE_MAP.keys())

MODEL_CLASSES = {
    "bert": (BertConfig, BertForMultipleChoice, BertTokenizer),
    "xlnet": (XLNetConfig, XLNetForMultipleChoice, XLNetTokenizer),
    "roberta": (RobertaConfig, RobertaForMultipleChoice, RobertaTokenizer),
    "xlm-roberta": (XLMRobertaConfig, XLMRobertaForMultipleChoice, XLMRobertaTokenizer),
    "bert-kb": (BertConfig, BertLMForMultipleChoice, BertTokenizer),
    "roberta-kb": (RobertaConfig, RobertaLMForMultipleChoice, RobertaTokenizer),
    "xlm-roberta-kb": (XLMRobertaConfig, XLMRobertaLMForMultipleChoice, XLMRobertaTokenizer),
    "distilbert": (DistilBertConfig, DistilBertLMForMultipleChoice, DistilBertTokenizer)
}


def select_field(features, field):
    return [[choice[field] for choice in feature.choices_features] for feature in features]


def simple_accuracy(preds, labels):
    return (preds == labels).mean()


def set_seed(args):
    random.seed(args.seed)
    np.random.seed(args.seed)
    torch.manual_seed(args.seed)
    if args.n_gpu > 0:
        torch.cuda.manual_seed_all(args.seed)


def train(args, train_dataset, model, tokenizer):
    """ Train the model """
    if args.local_rank in [-1, 0]:
        # tb_writer = SummaryWriter(logdir=args.tb_log_dir)
        tb_writer = SummaryWriter()
        pass

    args.train_batch_size = args.per_gpu_train_batch_size * max(1, args.n_gpu)
    train_sampler = (
        RandomSampler(train_dataset) if args.local_rank == -1 else DistributedSampler(train_dataset)
    )
    train_dataloader = DataLoader(
        train_dataset, sampler=train_sampler, batch_size=args.train_batch_size
    )

    if args.max_steps > 0:
        t_total = args.max_steps
        args.num_train_epochs = (
            args.max_steps // (len(train_dataloader) // args.gradient_accumulation_steps) + 1
        )
    else:
        t_total = len(train_dataloader) // args.gradient_accumulation_steps * args.num_train_epochs

    # Prepare optimizer and schedule (linear warmup and decay)
    no_decay = ["bias", "LayerNorm.weight"]
    optimizer_grouped_parameters = [
        {
            "params": [
                p for n, p in model.named_parameters() if not any(nd in n for nd in no_decay)
            ],
            "weight_decay": args.weight_decay,
        },
        {
            "params": [p for n, p in model.named_parameters() if any(nd in n for nd in no_decay)],
            "weight_decay": 0.0,
        },
    ]
    optimizer = AdamW(optimizer_grouped_parameters, lr=args.learning_rate, eps=args.adam_epsilon)
    scheduler = get_linear_schedule_with_warmup(
        optimizer,
        num_warmup_steps=int(args.warmup_proportion * t_total),
        num_training_steps=t_total,
    )
    if args.fp16:
        try:
            from apex import amp
        except ImportError:
            raise ImportError(
                "Please install apex from https://www.github.com/nvidia/apex to use fp16 training."
            )
        model, optimizer = amp.initialize(model, optimizer, opt_level=args.fp16_opt_level)

    # multi-gpu training (should be after apex fp16 initialization)
    if args.n_gpu > 1:
        model = torch.nn.DataParallel(model)

    # Distributed training (should be after apex fp16 initialization)
    if args.local_rank != -1:
        model = torch.nn.parallel.DistributedDataParallel(
            model,
            device_ids=[args.local_rank],
            output_device=args.local_rank,
            find_unused_parameters=True,
        )

    # Train!
    logger.info("***** Running training *****")
    logger.info("  Num examples = %d", len(train_dataset))
    logger.info("  Num Epochs = %d", args.num_train_epochs)
    logger.info("  Instantaneous batch size per GPU = %d", args.per_gpu_train_batch_size)
    logger.info(
        "  Total train batch size (w. parallel, distributed & accumulation) = %d",
        args.train_batch_size
        * args.gradient_accumulation_steps
        * (torch.distributed.get_world_size() if args.local_rank != -1 else 1),
    )
    logger.info("  Gradient Accumulation steps = %d", args.gradient_accumulation_steps)
    logger.info("  Total optimization steps = %d", t_total)

    global_step = 0
    tr_loss, logging_loss, tmp_loss = 0.0, 0.0, 0.0
    best_dev_acc = 0.0
    best_steps = 0
    model.zero_grad()
    train_iterator = trange(
        int(args.num_train_epochs), desc="Epoch", disable=args.local_rank not in [-1, 0]
    )
    set_seed(args)  # Added here for reproductibility
    for _ in train_iterator:
        epoch_iterator = tqdm(
            train_dataloader, desc="Iteration", disable=True
        )
        for step, batch in enumerate(epoch_iterator):
            model.train()
            batch = tuple(t.to(args.device) for t in batch)
            inputs = {
                "input_ids": batch[0],
                "attention_mask": batch[1],
                "token_type_ids": batch[2]
                if args.model_type in ["bert", "xlnet"]
                else None,  # XLM don't use segment_ids
            }
            labels = batch[3]

            outputs = model(**inputs)  # model outputs are always tuple in transformers (see doc)

            logits = outputs[0].masked_fill(batch[4] == 0, -10000)

            loss_fct = torch.nn.CrossEntropyLoss()
            loss = loss_fct(logits, labels)

            if args.n_gpu > 1:
                loss = loss.mean()  # mean() to average on multi-gpu parallel training
            if args.gradient_accumulation_steps > 1:
                loss = loss / args.gradient_accumulation_steps

            if args.fp16:
                with amp.scale_loss(loss, optimizer) as scaled_loss:
                    scaled_loss.backward()
                torch.nn.utils.clip_grad_norm_(amp.master_params(optimizer), args.max_grad_norm)
            else:
                loss.backward()
                torch.nn.utils.clip_grad_norm_(model.parameters(), args.max_grad_norm)

            tr_loss += loss.item()
            if (step + 1) % args.gradient_accumulation_steps == 0:

                optimizer.step()
                scheduler.step()  # Update learning rate schedule
                model.zero_grad()
                global_step += 1
                tb_writer.add_scalar("train_{}".format("loss_"), tr_loss - tmp_loss, global_step)
                tmp_loss = tr_loss

                if (
                    args.local_rank in [-1, 0]
                    and args.logging_steps > 0
                    and global_step % args.logging_steps == 0
                ):
                    # Log metrics
                    if (
                        args.local_rank == -1 and args.evaluate_during_training
                    ):  # Only evaluate when single GPU otherwise metrics may not average well
                        results = evaluate(args, model, tokenizer)
                        for key, value in results.items():
                            tb_writer.add_scalar("eval_{}".format(key), value, global_step)
                        if results["eval_acc"] > best_dev_acc:
                            best_dev_acc = results["eval_acc"]
                            best_steps = global_step
                            if args.do_test:
                                results_test = evaluate(args, model, tokenizer, test=True)
                                for key, value in results_test.items():
                                    tb_writer.add_scalar("test_{}".format(key), value, global_step)
                                logger.info(
                                    "test acc: %s, loss: %s, global steps: %s",
                                    str(results_test["eval_acc"]),
                                    str(results_test["eval_loss"]),
                                    str(global_step),
                                )
                    tb_writer.add_scalar("lr", scheduler.get_lr()[0], global_step)
                    tb_writer.add_scalar(
                        "loss", (tr_loss - logging_loss) / args.logging_steps, global_step
                    )
                    logger.info(
                        "Average loss: %s at global step: %s",
                        str((tr_loss - logging_loss) / args.logging_steps),
                        str(global_step),
                    )
                    logging_loss = tr_loss

                if (
                    args.local_rank in [-1, 0]
                    and args.save_steps > 0
                    and global_step % args.save_steps == 0
                ):
                    # Save model checkpoint
                    output_dir = os.path.join(args.output_dir, "checkpoint-{}".format(global_step))
                    if not os.path.exists(output_dir):
                        os.makedirs(output_dir)
                    model_to_save = (
                        model.module if hasattr(model, "module") else model
                    )  # Take care of distributed/parallel training
                    model_to_save.save_pretrained(output_dir)
                    tokenizer.save_vocabulary(output_dir)
                    torch.save(args, os.path.join(output_dir, "training_args.bin"))
                    logger.info("Saving model checkpoint to %s", output_dir)

            if args.max_steps > 0 and global_step > args.max_steps:
                epoch_iterator.close()
                break
        if args.max_steps > 0 and global_step > args.max_steps:
            train_iterator.close()
            break

    if args.local_rank in [-1, 0]:
        tb_writer.close()

    return global_step, tr_loss / global_step, best_steps


def evaluate(args, model, tokenizer, prefix="", test=False):
    eval_task_names = (args.task_name,)
    eval_outputs_dirs = (args.output_dir,)

    results = {}
    for eval_task, eval_output_dir in zip(eval_task_names, eval_outputs_dirs):
        eval_dataset, all_example_ids = load_and_cache_examples(
            args, eval_task, tokenizer, evaluate=not test, test=test
        )

        if not os.path.exists(eval_output_dir) and args.local_rank in [-1, 0]:
            os.makedirs(eval_output_dir)

        args.eval_batch_size = args.per_gpu_eval_batch_size * max(1, args.n_gpu)
        # Note that DistributedSampler samples randomly
        eval_sampler = SequentialSampler(eval_dataset)
        eval_dataloader = DataLoader(
            eval_dataset, sampler=eval_sampler, batch_size=args.eval_batch_size
        )

        # multi-gpu evaluate
        if args.n_gpu > 1:
            model = torch.nn.DataParallel(model)

        # Eval!
        logger.info("***** Running evaluation {} *****".format(prefix))
        logger.info("  Num examples = %d", len(eval_dataset))
        logger.info("  Batch size = %d", args.eval_batch_size)
        eval_loss = 0.0
        nb_eval_steps = 0
        preds = None
        preds_softmax = None
        out_label_ids = None
        for batch in tqdm(eval_dataloader, desc="Evaluating", disable = True):
            model.eval()
            batch = tuple(t.to(args.device) for t in batch)

            with torch.no_grad():
                inputs = {
                    "input_ids": batch[0],
                    "attention_mask": batch[1],
                    "token_type_ids": batch[2]
                    if args.model_type in ["bert", "xlnet"]
                    else None,  # XLM don't use segment_ids
                    "labels": batch[3],
                }

                if args.model_type in ["bert-kb", "roberta-kb", "xlm-roberta-kb"]:

                    masked_input_ids = batch[0].detach().cpu().numpy()
                    masked_input_ids = masked_input_ids.reshape(-1, masked_input_ids.shape[-1])
                    masked_positions = np.zeros_like(masked_input_ids, dtype=np.long)
                    attention_mask = batch[1].detach().cpu().numpy()
                    attention_mask = attention_mask.reshape(-1, attention_mask.shape[-1])
                    for i in range(len(masked_input_ids)):
                        sp = [
                            i
                            for i, x in enumerate(masked_input_ids[i])
                            if x == tokenizer.sep_token_id
                        ]
                        sep_start, sep_end = sp[-2:]
                        masked_input_ids[i, sep_start + 1 : sep_end] = tokenizer.mask_token_id
                        masked_positions[i, sep_start + 1 : sep_end] = 1
                        attention_mask[i, sp[:-1]] = 0

                    input_shape = inputs["input_ids"].shape
                    masked_input_ids = masked_input_ids.reshape(input_shape)
                    masked_positions = masked_positions.reshape(input_shape)
                    attention_mask = attention_mask.reshape(input_shape)
                    inputs["masked_input_ids"] = torch.LongTensor(masked_input_ids).to(args.device)
                    inputs["masked_positions"] = torch.LongTensor(masked_positions).to(args.device)
                    inputs["attention_mask"] = torch.LongTensor(attention_mask).to(args.device)

                outputs = model(**inputs)
                tmp_eval_loss, logits = outputs[:2]
                logits = logits.masked_fill(batch[4] == 0, -10000)

                eval_loss += tmp_eval_loss.mean().item()
            nb_eval_steps += 1
            if preds is None:
                preds = logits.detach().cpu().numpy()
                preds_softmax = torch.softmax(logits, -1).detach().cpu().numpy()
                out_label_ids = inputs["labels"].detach().cpu().numpy()
            else:
                preds = np.append(preds, logits.detach().cpu().numpy(), axis=0)
                preds_softmax = np.append(
                    preds_softmax, torch.softmax(logits, -1).detach().cpu().numpy(), axis=0
                )
                out_label_ids = np.append(
                    out_label_ids, inputs["labels"].detach().cpu().numpy(), axis=0
                )

        eval_loss = eval_loss / nb_eval_steps

        preds_softmax = [[round(x.tolist(), 4) for x in p] for p in preds_softmax]
        per_id_pred = dict(zip(all_example_ids, preds_softmax))

        preds = np.argmax(preds, axis=1)
        acc = simple_accuracy(preds, out_label_ids)
        result = {"eval_acc": acc, "eval_loss": eval_loss}
        results.update(result)

        label_annot = {0: "A", 1: "B", 2: "C", 3: "D"}
        out_labels = [label_annot[k] for k in out_label_ids.tolist()]
        pred_labels = [label_annot[j] for j in preds.tolist()]

        per_id_pred_label = {"pred": pred_labels, "truth": out_labels}

        output_eval_file = os.path.join(
            eval_output_dir, "is_test_" + str(test).lower() + "_eval_results.txt"
        )

        with open(output_eval_file, "w") as writer:
            logger.info("***** Eval results {} *****".format(str(prefix) + " is test:" + str(test)))
            writer.write("model           =%s\n" % str(args.model_name_or_path))
            writer.write(
                "total batch size=%d\n"
                % (
                    args.per_gpu_train_batch_size
                    * args.gradient_accumulation_steps
                    * (torch.distributed.get_world_size() if args.local_rank != -1 else 1)
                )
            )
            writer.write("train num epochs=%d\n" % args.num_train_epochs)
            writer.write("fp16            =%s\n" % args.fp16)
            writer.write("max seq length  =%d\n" % args.max_seq_length)
            for key in sorted(result.keys()):
                logger.info("  %s = %s", key, str(result[key]))
                writer.write("%s = %s\n" % (key, str(result[key])))

        if args.output_predictions:
            output_pred_file = os.path.join(
                eval_output_dir, "predictions_" + str(test).lower() + "_eval_results.json"
            )

            with open(output_pred_file, "w") as writer:
                json.dump(per_id_pred, writer, indent=4)
                logger.info("Saved {0}".format(output_pred_file))

            output_pred_file2 = os.path.join(
                eval_output_dir, "predictions_" + str(test).lower() + "_eval_results_labels.json"
            )

            with open(output_pred_file2, "w", encoding='utf-8') as writer:
                json.dump(per_id_pred_label, writer, indent=4)
                logger.info("Saved {0}".format(output_pred_file2))

    return results


def load_and_cache_examples(args, task, tokenizer, evaluate=False, test=False):
    if args.local_rank not in [-1, 0]:
        torch.distributed.barrier()  # Make sure only the first process in distributed training process the dataset, and the others will use the cache

    processor = (
        processors[args.task_name]()
        if args.task_name not in ["arc", "exams"]
        else processors[args.task_name](para_type=args.para_type)
    )
    # Load data features from cache or dataset file
    if evaluate:
        cached_mode = "dev"
    elif test:
        cached_mode = "test"
    else:
        cached_mode = "train"
    assert not (evaluate and test)
    cached_features_file = os.path.join(
        args.data_dir,
        "cached_{}_{}_{}_{}".format(
            cached_mode,
            "__".join(list(filter(None, args.model_name_or_path.split("/")))[-2:]),
            str(args.max_seq_length),
            str(task),
        ),
    )
    if os.path.exists(cached_features_file) and not args.overwrite_cache:
        logger.info("Loading features from cached file %s", cached_features_file)
        features = torch.load(cached_features_file)
    else:
        logger.info("Creating features from dataset file at %s", args.data_dir)
        label_list = processor.get_labels()
        if evaluate:
            examples = processor.get_dev_examples(args.data_dir)
        elif test:
            examples = processor.get_test_examples(args.data_dir)
        else:
            examples = processor.get_train_examples(args.data_dir)
        logger.info("Training number: %s", str(len(examples)))
        features = convert_examples_to_features(
            examples,
            label_list,
            args.max_seq_length,
            tokenizer,
            pad_on_left=bool(args.model_type in ["xlnet"]),  # pad on the left for xlnet
            pad_token_segment_id=tokenizer.pad_token_type_id,
            kb_masking=bool(args.model_type in ["bert-kb", "roberta-kb", "xlm-roberta-kb"]),
        )
        if args.local_rank in [-1, 0]:
            logger.info("Saving features into cached file %s", cached_features_file)
            torch.save(features, cached_features_file)

    if args.local_rank == 0:
        torch.distributed.barrier()  # Make sure only the first process in distributed training process the dataset, and the others will use the cache

    # Convert to Tensors and build dataset
    all_input_ids = torch.tensor(select_field(features, "input_ids"), dtype=torch.long)
    all_input_mask = torch.tensor(select_field(features, "input_mask"), dtype=torch.long)
    all_segment_ids = torch.tensor(select_field(features, "segment_ids"), dtype=torch.long)
    all_label_ids = torch.tensor([f.label for f in features], dtype=torch.long)
    all_answers_masks = torch.tensor([f.answers_mask for f in features], dtype=torch.long)

    dataset = TensorDataset(
        all_input_ids, all_input_mask, all_segment_ids, all_label_ids, all_answers_masks
    )

    if evaluate or test:
        all_example_ids = [x.example_id for x in features]

        return dataset, all_example_ids

    return dataset

# %%
print(ALL_MODELS)
# Out:
# ('distilbert-base-uncased', 'distilbert-base-uncased-distilled-squad', 'distilbert-base-cased', 'distilbert-base-cased-distilled-squad', 'distilbert-base-german-cased', 'distilbert-base-multilingual-cased', 'distilbert-base-uncased-finetuned-sst-2-english', 'bert-base-uncased', 'bert-large-uncased', 'bert-base-cased', 'bert-large-cased', 'bert-base-multilingual-uncased', 'bert-base-multilingual-cased', 'bert-base-chinese', 'bert-base-german-cased', 'bert-large-uncased-whole-word-masking', 'bert-large-cased-whole-word-masking', 'bert-large-uncased-whole-word-masking-finetuned-squad', 'bert-large-cased-whole-word-masking-finetuned-squad', 'bert-base-cased-finetuned-mrpc', 'bert-base-german-dbmdz-cased', 'bert-base-german-dbmdz-uncased', 'cl-tohoku/bert-base-japanese', 'cl-tohoku/bert-base-japanese-whole-word-masking', 'cl-tohoku/bert-base-japanese-char', 'cl-tohoku/bert-base-japanese-char-whole-word-masking', 'TurkuNLP/bert-base-finnish-cased-v1', 'TurkuNLP/bert-base-finnish-uncased-v1', 'wietsedv/bert-base-dutch-cased', 'xlm-roberta-base', 'xlm-roberta-large', 'xlm-roberta-large-finetuned-conll02-dutch', 'xlm-roberta-large-finetuned-conll02-spanish', 'xlm-roberta-large-finetuned-conll03-english', 'xlm-roberta-large-finetuned-conll03-german')

# %% [markdown]
# # Main

# %%
OUTPUT_DIR = 'drive/My Drive/CODE/ViMMRC/models/mbert_vimmrc2_2/'

# %% [markdown]
# ## Train

# %%
import logging, sys
logging.disable(sys.maxsize)


def main():
    parser = argparse.ArgumentParser()

    # Required parameters
    parser.add_argument(
        "--data_dir",
        default="drive/My Drive/CODE/ViMMRC/dataset/race_ver_2",
        type=str,
        help="The input data dir. Should contain the .tsv files (or other data files) for the task.",
    )

    parser.add_argument(
        "--model_type",
        default="bert",
        type=str,
        help="Model type selected in the list: " + ", ".join(MODEL_CLASSES.keys()),
    )
    parser.add_argument(
        "--model_name_or_path",
        default="bert-base-multilingual-cased",
        type=str,
        help="Path to pre-trained model or shortcut name selected in the list: "
        + ", ".join(ALL_MODELS),
    )
    
    parser.add_argument(
        "--task_name",
        default="race",
        type=str,
        help="The name of the task to train selected in the list: " + ", ".join(processors.keys()),
    )
    parser.add_argument(
        "--para_type",
        default="per_choice",
        type=str,
        choices=["per_choice", "concat_choices", "ignore"],
        help="Paragraph building strategy for ARC (default: %(default)s)",
    )
    parser.add_argument(
        "--output_predictions",
        default=True,
        type=bool,
        help="Whether to export the predictions from the eval step.",
    )
    parser.add_argument(
        "--output_dir",
        default=OUTPUT_DIR,
        type=str,
        help="The output directory where the model predictions and checkpoints will be written.",
    )
    parser.add_argument(
        "--freeze_embeddings", default=False, action="store_true", help="Whether to freeze the embeeding layer.",
    )
    parser.add_argument(
        "--freeze_layers", nargs="*", help="Whether to freeze the embeeding layer.",
    )

    # Other parameters
    parser.add_argument(
        "--tb_log_dir",
        default="",
        type=str,
        help="Tensorboard log dir for the current experiment",
    )

    parser.add_argument(
        "--config_name",
        default="",
        type=str,
        help="Pretrained config name or path if not the same as model_name",
    )
    parser.add_argument(
        "--tokenizer_name",
        default="",
        type=str,
        help="Pretrained tokenizer name or path if not the same as model_name",
    )
    parser.add_argument(
        "--cache_dir",
        default=OUTPUT_DIR,
        type=str,
        help="Where do you want to store the pre-trained models downloaded from s3",
    )
    parser.add_argument(
        "--max_seq_length",
        default=300,
        type=int,
        help="The maximum total input sequence length after tokenization. Sequences longer "
        "than this will be truncated, sequences shorter will be padded.",
    )
    parser.add_argument("--do_train", default = True, action="store_true", help="Whether to run training.")
    parser.add_argument(
        "--do_eval", default = True, action="store_true", help="Whether to run eval on the dev set."
    )
    parser.add_argument(
        "--do_test", default = False, action="store_true", help="Whether to run test on the test set"
    )
    parser.add_argument(
        "--evaluate_during_training",
        action="store_true",
        default = True,
        help="Run evaluation during training at each logging step.",
    )
    parser.add_argument(
        "--do_lower_case",
        action="store_true",
        default = False,
        help="Set this flag if you are using an uncased model.",
    )

    parser.add_argument(
        "--per_gpu_train_batch_size",
        default=4,
        type=int,
        help="Batch size per GPU/CPU for training.",
    )
    parser.add_argument(
        "--per_gpu_eval_batch_size",
        default=4,
        type=int,
        help="Batch size per GPU/CPU for evaluation.",
    )
    parser.add_argument(
        "--gradient_accumulation_steps",
        type=int,
        default=4,
        help="Number of updates steps to accumulate before performing a backward/update pass.",
    )
    parser.add_argument(
        "--learning_rate", default=1e-5, type=float, help="The initial learning rate for Adam."
    )
    parser.add_argument(
        "--weight_decay", default=0.0, type=float, help="Weight deay if we apply some."
    )
    parser.add_argument(
        "--adam_epsilon", default=1e-8, type=float, help="Epsilon for Adam optimizer."
    )
    parser.add_argument("--max_grad_norm", default=1.0, type=float, help="Max gradient norm.")
    parser.add_argument(
        "--num_train_epochs",
        default=50,
        type=float,
        help="Total number of training epochs to perform.",
    )
    parser.add_argument(
        "--max_steps",
        default=-1,
        type=int,
        help="If > 0: set total number of training steps to perform. Override num_train_epochs.",
    )
    parser.add_argument(
        "--warmup_proportion", default=0.1, type=float, help="Linear warmup over warmup_proportion."
    )

    parser.add_argument("--logging_steps", type=int, default=100, help="Log every X updates steps.")
    parser.add_argument(
        "--save_steps", type=int, default=500, help="Save checkpoint every X updates steps."
    )
    parser.add_argument(
        "--eval_all_checkpoints",
        default = True,
        action="store_true",
        help="Evaluate all checkpoints starting with the same prefix as model_name ending and ending with step number",
    )
    parser.add_argument("--no_cuda", default = False, action="store_true", help="Avoid using CUDA when available")
    parser.add_argument(
        "--overwrite_output_dir",
        default = True,
        action="store_true",
        help="Overwrite the content of the output directory",
    )
    parser.add_argument(
        "--overwrite_cache",
        default = True,
        action="store_true",
        help="Overwrite the cached training and evaluation sets",
    )
    parser.add_argument("--seed", type=int, default=42, help="random seed for initialization")

    parser.add_argument(
        "--fp16",
        action="store_true",
        help="Whether to use 16-bit (mixed) precision (through NVIDIA apex) instead of 32-bit",
    )
    parser.add_argument(
        "--fp16_opt_level",
        type=str,
        default="O1",
        help="For fp16: Apex AMP optimization level selected in ['O0', 'O1', 'O2', and 'O3']."
        "See details at https://nvidia.github.io/apex/amp.html",
    )
    parser.add_argument(
        "--local_rank", type=int, default=-1, help="For distributed training: local_rank"
    )
    parser.add_argument("--server_ip", type=str, default="", help="For distant debugging.")
    parser.add_argument("--server_port", type=str, default="", help="For distant debugging.")

    parser.add_argument('-f')

    args = parser.parse_args()

    options_print = ""
    logger.info("Arg Options - input:")
    for arg in vars(args):
        options_print += "opt: %s=%s\r\n" % (arg, getattr(args, arg))
    logger.info(options_print)

    if (
        os.path.exists(args.output_dir)
        and os.listdir(args.output_dir)
        and args.do_train
        and not args.overwrite_output_dir
    ):
        raise ValueError(
            "Output directory ({}) already exists and is not empty. Use --overwrite_output_dir to overcome.".format(
                args.output_dir
            )
        )

    # Setup distant debugging if needed
    if args.server_ip and args.server_port:
        # Distant debugging - see https://code.visualstudio.com/docs/python/debugging#_attach-to-a-local-script
        import ptvsd

        print("Waiting for debugger attach")
        ptvsd.enable_attach(address=(args.server_ip, args.server_port), redirect_output=True)
        ptvsd.wait_for_attach()

    # Setup CUDA, GPU & distributed training
    if args.local_rank == -1 or args.no_cuda:
        device = torch.device("cuda" if torch.cuda.is_available() and not args.no_cuda else "cpu")
        args.n_gpu = 0 if args.no_cuda else torch.cuda.device_count()
    else:  # Initializes the distributed backend which will take care of sychronizing nodes/GPUs
        torch.cuda.set_device(args.local_rank)
        device = torch.device("cuda", args.local_rank)
        torch.distributed.init_process_group(backend="nccl")
        args.n_gpu = 1
    args.device = device

    # Setup logging
    logging.basicConfig(
        format="%(asctime)s - %(levelname)s - %(name)s -   %(message)s",
        datefmt="%m/%d/%Y %H:%M:%S",
        level=logging.INFO if args.local_rank in [-1, 0] else logging.WARN,
    )
    logger.warning(
        "Process rank: %s, device: %s, n_gpu: %s, distributed training: %s, 16-bits training: %s",
        args.local_rank,
        device,
        args.n_gpu,
        bool(args.local_rank != -1),
        args.fp16,
    )

    # Set seed
    set_seed(args)

    # Prepare GLUE task
    args.task_name = args.task_name.lower()
    if args.task_name not in processors:
        raise ValueError("Task not found: %s" % (args.task_name))
    processor = (
        processors[args.task_name]()
        if args.task_name not in ["arc", "exams",]
        else processors[args.task_name](para_type=args.para_type)
    )
    label_list = processor.get_labels()
    num_labels = len(label_list)

    # Load pretrained model and tokenizer
    if args.local_rank not in [-1, 0]:
        torch.distributed.barrier()  # Make sure only the first process in distributed training will download model & vocab

    args.model_type = args.model_type.lower()
    config_class, model_class, tokenizer_class = MODEL_CLASSES[args.model_type]
    config = config_class.from_pretrained(
        args.config_name if args.config_name else args.model_name_or_path,
        num_labels=num_labels,
        early_stopping = True,
        finetuning_task=args.task_name,
        cache_dir=args.cache_dir if args.cache_dir else None,
    )
    tokenizer = tokenizer_class.from_pretrained(
        args.tokenizer_name if args.tokenizer_name else args.model_name_or_path,
        do_lower_case=args.do_lower_case,
        cache_dir=args.cache_dir if args.cache_dir else None,
    )
    model = model_class.from_pretrained(
        args.model_name_or_path,
        from_tf=bool(".ckpt" in args.model_name_or_path),
        config=config,
        cache_dir=args.cache_dir if args.cache_dir else None,
    )

    if args.local_rank == 0:
        torch.distributed.barrier()  # Make sure only the first process in distributed training will download model & vocab

    options_print = ""
    logging.info("Arg Options:")
    for arg in vars(args):
        options_print += "opt: %s=%s\r\n" % (arg, getattr(args, arg))
    logging.info(options_print)

    model.to(args.device)

    def get_model_base_obj(model, model_type):
        if model_type == "bert":
            return model.bert
        elif model_type == "xlm-roberta" or model_type == "roberta":
            return model.roberta
        elif model_type == "distilbert":
            return model.distilbert    
        else:
            raise ValueError("model_type='{0}' is not supported!")

    if args.freeze_embeddings:
        for param in list(get_model_base_obj(model, args.model_type).embeddings.parameters()):
            param.requires_grad = False
        logger.info("Froze Embedding Layer")

    # freeze_layers is a string "1,2,3" representing layer number
    if args.freeze_layers:
        layer_indexes = [int(x) for x in args.freeze_layers]
        for layer_idx in layer_indexes:
            for param in list(
                get_model_base_obj(model, args.model_type).encoder.layer[layer_idx].parameters()
            ):
                param.requires_grad = False
            logger.info("Froze Layer: %s", layer_idx)

    logger.info("Training/evaluation parameters %s", args)
    best_steps = 0

    # Training
    if args.do_train:
        train_dataset = load_and_cache_examples(args, args.task_name, tokenizer, evaluate=False)
        global_step, tr_loss, best_steps = train(args, train_dataset, model, tokenizer)
        logger.info(" global_step = %s, average loss = %s", global_step, tr_loss)

    # Saving best-practices: if you use defaults names for the model, you can reload it using from_pretrained()
    if args.do_train and (args.local_rank == -1 or torch.distributed.get_rank() == 0):
        # Create output directory if needed
        if not os.path.exists(args.output_dir) and args.local_rank in [-1, 0]:
            os.makedirs(args.output_dir)

        logger.info("Saving model checkpoint to %s", args.output_dir)
        # Save a trained model, configuration and tokenizer using `save_pretrained()`.
        # They can then be reloaded using `from_pretrained()`
        model_to_save = (
            model.module if hasattr(model, "module") else model
        )  # Take care of distributed/parallel training
        model_to_save.save_pretrained(args.output_dir)
        tokenizer.save_pretrained(args.output_dir)

        # Good practice: save your training arguments together with the trained model
        torch.save(args, os.path.join(args.output_dir, "training_args.bin"))

        # Load a trained model and vocabulary that you have fine-tuned
        model = model_class.from_pretrained(args.output_dir)
        tokenizer = tokenizer_class.from_pretrained(args.output_dir)
        model.to(args.device)

    # Evaluation
    results = {}
    if args.do_eval and args.local_rank in [-1, 0]:
        if not args.do_train:
            args.output_dir = args.model_name_or_path
        checkpoints = [args.output_dir]
        if args.eval_all_checkpoints:
            checkpoints = list(
                os.path.dirname(c)
                for c in sorted(glob.glob(args.output_dir + "/**/" + WEIGHTS_NAME, recursive=True))
            )
            logging.getLogger("transformers.modeling_utils").setLevel(
                logging.WARN
            )  # Reduce logging
        logger.info("Evaluate the following checkpoints: %s", checkpoints)
        for checkpoint in checkpoints:
            global_step = checkpoint.split("-")[-1] if len(checkpoints) > 1 else ""
            prefix = checkpoint.split("/")[-1] if checkpoint.find("checkpoint") != -1 else ""

            model = model_class.from_pretrained(checkpoint)
            model.to(args.device)
            result = evaluate(args, model, tokenizer, prefix=prefix)
            result = dict((k + "_{}".format(global_step), v) for k, v in result.items())
            results.update(result)

    if args.do_test and args.local_rank in [-1, 0]:
        checkpoints = [args.model_name_or_path]
        logger.info("Evaluate the following checkpoints: %s", checkpoints)
        for checkpoint in checkpoints:
            global_step = checkpoint.split("-")[-1] if len(checkpoints) > 1 else ""
            prefix = checkpoint.split("/")[-1] if checkpoint.find("checkpoint") != -1 else ""

            model = model_class.from_pretrained(checkpoint)
            model.to(args.device)
            result = evaluate(args, model, tokenizer, prefix=prefix, test=True)
            result = dict((k + "_{}".format(global_step), v) for k, v in result.items())
            results.update(result)
    if best_steps:
        logger.info("best steps of eval acc is the following checkpoints: %s", best_steps)
    return results


if __name__ == "__main__":
    main()
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
# convert examples to features: 417it [00:18,  7.47it/s]
# convert examples to features: 420it [00:18,  9.38it/s]
# convert examples to features: 423it [00:18, 10.66it/s]
# convert examples to features: 425it [00:18, 11.71it/s]
# convert examples to features: 427it [00:18, 12.61it/s]
# convert examples to features: 429it [00:18, 13.39it/s]
# convert examples to features: 431it [00:19, 13.81it/s]
# convert examples to features: 433it [00:19, 14.25it/s]
# convert examples to features: 436it [00:19, 16.22it/s]
# convert examples to features: 440it [00:19, 19.05it/s]
# convert examples to features: 444it [00:19, 21.62it/s]
# convert examples to features: 452it [00:19, 27.45it/s]
# convert examples to features: 460it [00:19, 33.83it/s]
# convert examples to features: 468it [00:19, 40.64it/s]
# convert examples to features: 475it [00:20, 44.59it/s]
# convert examples to features: 481it [00:20, 36.52it/s]
# convert examples to features: 486it [00:20, 32.24it/s]
# convert examples to features: 491it [00:20, 29.93it/s]
# convert examples to features: 498it [00:20, 36.13it/s]
# convert examples to features: 506it [00:20, 42.71it/s]
# convert examples to features: 512it [00:20, 45.97it/s]
# convert examples to features: 518it [00:21, 48.61it/s]
# convert examples to features: 524it [00:21, 16.61it/s]
# convert examples to features: 529it [00:23,  9.29it/s]
# convert examples to features: 532it [00:23,  7.07it/s]
# convert examples to features: 535it [00:24,  6.08it/s]
# convert examples to features: 537it [00:24,  5.49it/s]
# convert examples to features: 548it [00:24,  7.66it/s]
# convert examples to features: 556it [00:25, 10.50it/s]
# convert examples to features: 564it [00:25, 22.26it/s]
#
# convert examples to features: 0it [00:00, ?it/s]
# convert examples to features: 13it [00:00, 119.57it/s]
# convert examples to features: 23it [00:00, 111.77it/s]
# convert examples to features: 34it [00:00, 108.03it/s]
# convert examples to features: 44it [00:00, 102.90it/s]
# convert examples to features: 55it [00:00, 102.24it/s]
# convert examples to features: 68it [00:00, 108.69it/s]
# convert examples to features: 81it [00:00, 113.09it/s]
# convert examples to features: 92it [00:00, 102.01it/s]
# convert examples to features: 102it [00:01, 93.62it/s]
# convert examples to features: 112it [00:01, 90.35it/s]
# convert examples to features: 122it [00:01, 90.06it/s]
# convert examples to features: 131it [00:01, 78.63it/s]
# convert examples to features: 140it [00:01, 79.72it/s]
# convert examples to features: 153it [00:01, 87.87it/s]
# convert examples to features: 163it [00:01, 79.72it/s]
# convert examples to features: 172it [00:01, 73.93it/s]
# convert examples to features: 180it [00:02, 71.50it/s]
# convert examples to features: 188it [00:02, 69.75it/s]
# convert examples to features: 196it [00:02, 66.71it/s]
# convert examples to features: 203it [00:02, 65.33it/s]
# convert examples to features: 210it [00:02, 63.60it/s]
# convert examples to features: 217it [00:02, 63.15it/s]
# convert examples to features: 224it [00:02, 63.52it/s]
# convert examples to features: 231it [00:02, 61.96it/s]
# convert examples to features: 238it [00:02, 57.59it/s]
# convert examples to features: 244it [00:03, 56.20it/s]
# convert examples to features: 254it [00:03, 63.97it/s]
# convert examples to features: 268it [00:03, 76.12it/s]
# convert examples to features: 277it [00:03, 77.79it/s]
# convert examples to features: 286it [00:03, 77.05it/s]
# convert examples to features: 295it [00:04, 34.66it/s]
# convert examples to features: 302it [00:04, 31.78it/s]
# convert examples to features: 308it [00:04, 28.67it/s]
# convert examples to features: 313it [00:04, 23.88it/s]
# convert examples to features: 317it [00:05, 25.09it/s]
# convert examples to features: 321it [00:05, 27.41it/s]
# convert examples to features: 325it [00:05, 29.30it/s]
# convert examples to features: 329it [00:05, 29.88it/s]
# convert examples to features: 333it [00:05, 25.15it/s]
# convert examples to features: 336it [00:05, 21.63it/s]
# convert examples to features: 339it [00:06, 20.63it/s]
# convert examples to features: 342it [00:06, 22.66it/s]
# convert examples to features: 345it [00:06, 24.03it/s]
# convert examples to features: 348it [00:06, 24.02it/s]
# convert examples to features: 351it [00:06, 25.26it/s]
# convert examples to features: 354it [00:06, 24.90it/s]
# convert examples to features: 357it [00:06, 25.38it/s]
# convert examples to features: 360it [00:06, 22.48it/s]
# convert examples to features: 363it [00:07, 21.47it/s]
# convert examples to features: 366it [00:07, 20.67it/s]
# convert examples to features: 369it [00:07, 16.50it/s]
# convert examples to features: 371it [00:07, 10.50it/s]
# convert examples to features: 373it [00:08,  8.47it/s]
# convert examples to features: 375it [00:08,  7.59it/s]
# convert examples to features: 377it [00:08,  7.07it/s]
# convert examples to features: 378it [00:08,  6.48it/s]
# convert examples to features: 379it [00:09,  6.30it/s]
# convert examples to features: 380it [00:09,  6.20it/s]
# convert examples to features: 381it [00:09,  6.11it/s]
# convert examples to features: 382it [00:09,  6.06it/s]
# convert examples to features: 383it [00:09,  4.80it/s]
# convert examples to features: 384it [00:10,  4.10it/s]
# convert examples to features: 385it [00:10,  3.79it/s]
# convert examples to features: 386it [00:10,  3.59it/s]
# convert examples to features: 387it [00:11,  3.46it/s]
# convert examples to features: 388it [00:11,  3.39it/s]
# convert examples to features: 389it [00:11,  3.32it/s]
# convert examples to features: 390it [00:12,  3.25it/s]
# convert examples to features: 391it [00:12,  3.25it/s]
# convert examples to features: 392it [00:12,  3.23it/s]
# convert examples to features: 393it [00:13,  3.19it/s]
# convert examples to features: 394it [00:13,  3.18it/s]
# convert examples to features: 395it [00:13,  3.16it/s]
# convert examples to features: 396it [00:14,  3.15it/s]
# convert examples to features: 397it [00:14,  3.15it/s]
# convert examples to features: 398it [00:14,  3.09it/s]
# convert examples to features: 399it [00:15,  3.09it/s]
# convert examples to features: 400it [00:15,  3.10it/s]
# convert examples to features: 401it [00:15,  3.10it/s]
# convert examples to features: 402it [00:15,  3.10it/s]
# convert examples to features: 403it [00:16,  3.11it/s]
# convert examples to features: 404it [00:16,  3.11it/s]
# convert examples to features: 405it [00:16,  3.12it/s]
# convert examples to features: 406it [00:17,  3.12it/s]
# convert examples to features: 407it [00:17,  3.12it/s]
# convert examples to features: 408it [00:17,  3.12it/s]
# convert examples to features: 411it [00:18,  4.27it/s]
# convert examples to features: 414it [00:18,  5.74it/s]
# convert examples to features: 417it [00:18,  7.49it/s]
# convert examples to features: 420it [00:18,  9.36it/s]
# convert examples to features: 423it [00:18, 10.66it/s]
# convert examples to features: 425it [00:18, 11.34it/s]
# convert examples to features: 427it [00:18, 12.34it/s]
# convert examples to features: 429it [00:18, 13.14it/s]
# convert examples to features: 431it [00:19, 13.64it/s]
# convert examples to features: 433it [00:19, 14.10it/s]
# convert examples to features: 436it [00:19, 16.12it/s]
# convert examples to features: 440it [00:19, 19.01it/s]
# convert examples to features: 443it [00:19, 21.35it/s]
# convert examples to features: 448it [00:19, 25.66it/s]
# convert examples to features: 458it [00:19, 32.79it/s]
# convert examples to features: 466it [00:19, 39.55it/s]
# convert examples to features: 474it [00:20, 46.11it/s]
# convert examples to features: 481it [00:20, 37.11it/s]
# convert examples to features: 487it [00:20, 32.86it/s]
# convert examples to features: 492it [00:20, 30.26it/s]
# convert examples to features: 503it [00:20, 38.19it/s]
# convert examples to features: 509it [00:20, 42.51it/s]
# convert examples to features: 515it [00:21, 46.29it/s]
# convert examples to features: 521it [00:21, 32.72it/s]
# convert examples to features: 526it [00:22, 11.39it/s]
# convert examples to features: 530it [00:23,  7.87it/s]
# convert examples to features: 533it [00:23,  6.45it/s]
# convert examples to features: 535it [00:24,  5.71it/s]
# convert examples to features: 537it [00:24,  5.28it/s]
# convert examples to features: 547it [00:24,  7.38it/s]
# convert examples to features: 555it [00:25, 10.13it/s]
# convert examples to features: 564it [00:25, 22.23it/s]
# Epoch:  64%|██████▍   | 32/50 [1:17:28<45:06, 150.36s/it]
# convert examples to features: 0it [00:00, ?it/s]
# convert examples to features: 13it [00:00, 119.56it/s]
# convert examples to features: 23it [00:00, 111.00it/s]
# convert examples to features: 34it [00:00, 107.23it/s]
# convert examples to features: 42it [00:00, 96.49it/s]
# convert examples to features: 53it [00:00, 98.44it/s]
# convert examples to features: 63it [00:00, 98.57it/s]
# convert examples to features: 78it [00:00, 108.86it/s]
# convert examples to features: 89it [00:00, 99.94it/s]
# convert examples to features: 99it [00:00, 94.69it/s]
# convert examples to features: 109it [00:01, 85.21it/s]
# convert examples to features: 119it [00:01, 88.30it/s]
# convert examples to features: 128it [00:01, 82.92it/s]
# convert examples to features: 137it [00:01, 76.97it/s]
# convert examples to features: 151it [00:01, 88.70it/s]
# convert examples to features: 161it [00:01, 80.93it/s]
# convert examples to features: 170it [00:01, 69.70it/s]
# convert examples to features: 178it [00:02, 67.70it/s]
# convert examples to features: 186it [00:02, 65.12it/s]
# convert examples to features: 193it [00:02, 65.48it/s]
# convert examples to features: 200it [00:02, 65.87it/s]
# convert examples to features: 207it [00:02, 63.35it/s]
# convert examples to features: 214it [00:02, 63.05it/s]
# convert examples to features: 221it [00:02, 63.06it/s]
# convert examples to features: 228it [00:02, 64.21it/s]
# convert examples to features: 235it [00:02, 58.40it/s]
# convert examples to features: 241it [00:03, 56.46it/s]
# convert examples to features: 247it [00:03, 56.92it/s]
# convert examples to features: 259it [00:03, 67.47it/s]
# convert examples to features: 272it [00:03, 77.61it/s]
# convert examples to features: 281it [00:03, 77.14it/s]
# convert examples to features: 290it [00:03, 52.57it/s]
# convert examples to features: 297it [00:04, 29.90it/s]
# convert examples to features: 303it [00:04, 30.39it/s]
# convert examples to features: 308it [00:04, 26.78it/s]
# convert examples to features: 312it [00:04, 21.91it/s]
# convert examples to features: 316it [00:05, 23.19it/s]
# convert examples to features: 320it [00:05, 25.70it/s]
# convert examples to features: 324it [00:05, 27.86it/s]
# convert examples to features: 328it [00:05, 29.57it/s]
# convert examples to features: 332it [00:05, 26.72it/s]
# convert examples to features: 335it [00:05, 22.19it/s]
# convert examples to features: 338it [00:06, 19.91it/s]
# convert examples to features: 341it [00:06, 22.03it/s]
# convert examples to features: 344it [00:06, 23.55it/s]
# convert examples to features: 347it [00:06, 24.84it/s]
# convert examples to features: 350it [00:06, 25.62it/s]
# convert examples to features: 353it [00:06, 26.35it/s]
# convert examples to features: 356it [00:06, 26.75it/s]
# convert examples to features: 359it [00:06, 24.10it/s]
# convert examples to features: 362it [00:06, 22.37it/s]
# convert examples to features: 365it [00:07, 21.37it/s]
# convert examples to features: 368it [00:07, 20.79it/s]
# convert examples to features: 371it [00:07, 12.09it/s]
# convert examples to features: 373it [00:08,  9.28it/s]
# convert examples to features: 375it [00:08,  7.83it/s]
# convert examples to features: 377it [00:08,  7.21it/s]
# convert examples to features: 378it [00:08,  6.73it/s]
# convert examples to features: 379it [00:09,  6.46it/s]
# convert examples to features: 380it [00:09,  6.29it/s]
# convert examples to features: 381it [00:09,  6.17it/s]
# convert examples to features: 382it [00:09,  6.09it/s]
# convert examples to features: 383it [00:09,  4.82it/s]
# convert examples to features: 384it [00:10,  4.13it/s]
# convert examples to features: 385it [00:10,  3.81it/s]
# convert examples to features: 386it [00:10,  3.56it/s]
# convert examples to features: 387it [00:11,  3.46it/s]
# convert examples to features: 388it [00:11,  3.39it/s]
# convert examples to features: 389it [00:11,  3.33it/s]
# convert examples to features: 390it [00:12,  3.30it/s]
# convert examples to features: 391it [00:12,  3.27it/s]
# convert examples to features: 392it [00:12,  3.25it/s]
# convert examples to features: 393it [00:13,  3.21it/s]
# convert examples to features: 394it [00:13,  3.18it/s]
# convert examples to features: 395it [00:13,  3.16it/s]
# convert examples to features: 396it [00:14,  3.15it/s]
# convert examples to features: 397it [00:14,  3.15it/s]
# convert examples to features: 398it [00:14,  3.14it/s]
# convert examples to features: 399it [00:15,  3.14it/s]
# convert examples to features: 400it [00:15,  3.09it/s]
# convert examples to features: 401it [00:15,  3.10it/s]
# convert examples to features: 402it [00:15,  3.10it/s]
# convert examples to features: 403it [00:16,  3.12it/s]
# convert examples to features: 404it [00:16,  3.07it/s]
# convert examples to features: 405it [00:16,  3.03it/s]
# convert examples to features: 406it [00:17,  3.05it/s]
# convert examples to features: 407it [00:17,  3.04it/s]
# convert examples to features: 408it [00:17,  3.06it/s]
# convert examples to features: 411it [00:18,  4.18it/s]
# convert examples to features: 414it [00:18,  5.64it/s]
# convert examples to features: 417it [00:18,  7.43it/s]
# convert examples to features: 420it [00:18,  9.32it/s]
# convert examples to features: 423it [00:18, 10.62it/s]
# convert examples to features: 425it [00:18, 11.71it/s]
# convert examples to features: 427it [00:18, 12.58it/s]
# convert examples to features: 429it [00:18, 13.30it/s]
# convert examples to features: 431it [00:19, 13.75it/s]
# convert examples to features: 433it [00:19, 14.24it/s]
# convert examples to features: 436it [00:19, 16.24it/s]
# convert examples to features: 440it [00:19, 19.06it/s]
# convert examples to features: 444it [00:19, 21.70it/s]
# convert examples to features: 450it [00:19, 26.64it/s]
# convert examples to features: 460it [00:19, 33.74it/s]
# convert examples to features: 468it [00:19, 40.58it/s]
# convert examples to features: 475it [00:20, 44.74it/s]
# convert examples to features: 481it [00:20, 36.66it/s]
# convert examples to features: 486it [00:20, 31.53it/s]
# convert examples to features: 491it [00:20, 29.43it/s]
# convert examples to features: 499it [00:20, 35.98it/s]
# convert examples to features: 506it [00:20, 41.93it/s]
# convert examples to features: 512it [00:21, 45.80it/s]
# convert examples to features: 518it [00:21, 48.48it/s]
# convert examples to features: 524it [00:22, 16.34it/s]
# convert examples to features: 529it [00:23,  9.20it/s]
# convert examples to features: 532it [00:23,  7.04it/s]
# convert examples to features: 535it [00:24,  6.06it/s]
# convert examples to features: 537it [00:24,  5.48it/s]
# convert examples to features: 547it [00:25,  7.65it/s]
# convert examples to features: 554it [00:25, 10.39it/s]
# convert examples to features: 559it [00:25, 13.42it/s]
# convert examples to features: 564it [00:25, 22.17it/s]
#
# convert examples to features: 0it [00:00, ?it/s]
# convert examples to features: 13it [00:00, 119.43it/s]
# convert examples to features: 23it [00:00, 111.06it/s]
# convert examples to features: 34it [00:00, 107.46it/s]
# convert examples to features: 44it [00:00, 102.97it/s]
# convert examples to features: 55it [00:00, 102.33it/s]
# convert examples to features: 68it [00:00, 108.79it/s]
# convert examples to features: 79it [00:00, 106.99it/s]
# convert examples to features: 89it [00:00, 98.06it/s]
# convert examples to features: 99it [00:00, 93.50it/s]
# convert examples to features: 109it [00:01, 87.76it/s]
# convert examples to features: 119it [00:01, 90.21it/s]
# convert examples to features: 128it [00:01, 84.99it/s]
# convert examples to features: 137it [00:01, 78.28it/s]
# convert examples to features: 151it [00:01, 89.57it/s]
# convert examples to features: 161it [00:01, 81.28it/s]
# convert examples to features: 170it [00:01, 73.16it/s]
# convert examples to features: 178it [00:01, 72.57it/s]
# convert examples to features: 186it [00:02, 68.53it/s]
# convert examples to features: 194it [00:02, 67.22it/s]
# convert examples to features: 201it [00:02, 67.60it/s]
# convert examples to features: 208it [00:02, 65.44it/s]
# convert examples to features: 215it [00:02, 64.28it/s]
# convert examples to features: 222it [00:02, 64.39it/s]
# convert examples to features: 229it [00:02, 65.37it/s]
# convert examples to features: 236it [00:02, 58.38it/s]
# convert examples to features: 243it [00:03, 56.99it/s]
# convert examples to features: 251it [00:03, 62.27it/s]
# convert examples to features: 265it [00:03, 74.24it/s]
# convert examples to features: 275it [00:03, 79.47it/s]
# convert examples to features: 284it [00:03, 77.99it/s]
# convert examples to features: 293it [00:03, 40.41it/s]
# convert examples to features: 300it [00:04, 30.46it/s]
# convert examples to features: 306it [00:04, 30.65it/s]
# convert examples to features: 311it [00:04, 23.80it/s]
# convert examples to features: 315it [00:05, 23.42it/s]
# convert examples to features: 319it [00:05, 25.60it/s]
# convert examples to features: 323it [00:05, 27.73it/s]
# convert examples to features: 327it [00:05, 29.41it/s]
# convert examples to features: 331it [00:05, 28.36it/s]
# convert examples to features: 335it [00:05, 22.93it/s]
# convert examples to features: 338it [00:05, 20.29it/s]
# convert examples to features: 341it [00:06, 22.23it/s]
# convert examples to features: 344it [00:06, 23.58it/s]
# convert examples to features: 347it [00:06, 23.77it/s]
# convert examples to features: 350it [00:06, 24.28it/s]
# convert examples to features: 353it [00:06, 24.14it/s]
# convert examples to features: 357it [00:06, 25.01it/s]
# convert examples to features: 360it [00:06, 22.91it/s]
# convert examples to features: 363it [00:07, 21.65it/s]
# convert examples to features: 366it [00:07, 20.69it/s]
# convert examples to features: 369it [00:07, 16.46it/s]
# convert examples to features: 371it [00:07, 10.77it/s]
# convert examples to features: 373it [00:08,  8.72it/s]
# convert examples to features: 375it [00:08,  7.68it/s]
# convert examples to features: 377it [00:08,  7.12it/s]
# convert examples to features: 378it [00:08,  6.71it/s]
# convert examples to features: 379it [00:09,  6.45it/s]
# convert examples to features: 380it [00:09,  6.29it/s]
# convert examples to features: 381it [00:09,  6.18it/s]
# convert examples to features: 382it [00:09,  6.11it/s]
# convert examples to features: 383it [00:09,  4.81it/s]
# convert examples to features: 384it [00:10,  4.11it/s]
# convert examples to features: 385it [00:10,  3.79it/s]
# convert examples to features: 386it [00:10,  3.60it/s]
# convert examples to features: 387it [00:11,  3.48it/s]
# convert examples to features: 388it [00:11,  3.41it/s]
# convert examples to features: 389it [00:11,  3.35it/s]
# convert examples to features: 390it [00:12,  3.32it/s]
# convert examples to features: 391it [00:12,  3.29it/s]
# convert examples to features: 392it [00:12,  3.27it/s]
# convert examples to features: 393it [00:13,  3.22it/s]
# convert examples to features: 394it [00:13,  3.19it/s]
# convert examples to features: 395it [00:13,  3.18it/s]
# convert examples to features: 396it [00:14,  3.18it/s]
# convert examples to features: 397it [00:14,  3.17it/s]
# convert examples to features: 398it [00:14,  3.15it/s]
# convert examples to features: 399it [00:14,  3.14it/s]
# convert examples to features: 400it [00:15,  3.13it/s]
# convert examples to features: 401it [00:15,  3.13it/s]
# convert examples to features: 402it [00:15,  3.13it/s]
# convert examples to features: 403it [00:16,  3.12it/s]
# convert examples to features: 404it [00:16,  3.13it/s]
# convert examples to features: 405it [00:16,  3.13it/s]
# convert examples to features: 406it [00:17,  3.13it/s]
# convert examples to features: 407it [00:17,  3.13it/s]
# convert examples to features: 408it [00:17,  3.10it/s]
# convert examples to features: 411it [00:17,  4.23it/s]
# convert examples to features: 414it [00:18,  5.70it/s]
# convert examples to features: 417it [00:18,  7.51it/s]
# convert examples to features: 420it [00:18,  9.41it/s]
# convert examples to features: 423it [00:18, 10.70it/s]
# convert examples to features: 425it [00:18, 11.75it/s]
# convert examples to features: 427it [00:18, 12.70it/s]
# convert examples to features: 429it [00:18, 13.49it/s]
# convert examples to features: 431it [00:19, 13.91it/s]
# convert examples to features: 433it [00:19, 14.34it/s]
# convert examples to features: 436it [00:19, 16.33it/s]
# convert examples to features: 440it [00:19, 19.13it/s]
# convert examples to features: 444it [00:19, 21.72it/s]
# convert examples to features: 452it [00:19, 27.59it/s]
# convert examples to features: 461it [00:19, 34.61it/s]
# convert examples to features: 469it [00:19, 41.40it/s]
# convert examples to features: 476it [00:19, 43.47it/s]
# convert examples to features: 482it [00:20, 35.99it/s]
# convert examples to features: 487it [00:20, 32.05it/s]
# convert examples to features: 492it [00:20, 29.82it/s]
# convert examples to features: 503it [00:20, 37.65it/s]
# convert examples to features: 509it [00:20, 41.28it/s]
# convert examples to features: 515it [00:20, 45.16it/s]
# convert examples to features: 521it [00:21, 32.25it/s]
# convert examples to features: 526it [00:22, 11.26it/s]
# convert examples to features: 530it [00:23,  7.82it/s]
# convert examples to features: 533it [00:23,  6.44it/s]
# convert examples to features: 535it [00:24,  5.70it/s]
# convert examples to features: 537it [00:24,  5.25it/s]
# convert examples to features: 548it [00:24,  7.34it/s]
# convert examples to features: 556it [00:24, 10.07it/s]
# convert examples to features: 564it [00:25, 22.30it/s]
# Epoch:  66%|██████▌   | 33/50 [1:19:42<41:11, 145.37s/it]
# convert examples to features: 0it [00:00, ?it/s]
# convert examples to features: 13it [00:00, 119.43it/s]
# convert examples to features: 22it [00:00, 105.86it/s]
# convert examples to features: 33it [00:00, 104.51it/s]
# convert examples to features: 43it [00:00, 100.13it/s]
# convert examples to features: 52it [00:00, 96.38it/s]
# convert examples to features: 62it [00:00, 95.93it/s]
# convert examples to features: 71it [00:00, 71.35it/s]
# convert examples to features: 82it [00:00, 79.73it/s]
# convert examples to features: 91it [00:01, 80.00it/s]
# convert examples to features: 100it [00:01, 80.01it/s]
# convert examples to features: 109it [00:01, 79.23it/s]
# convert examples to features: 119it [00:01, 83.31it/s]
# convert examples to features: 128it [00:01, 80.25it/s]
# convert examples to features: 137it [00:01, 75.61it/s]
# convert examples to features: 150it [00:01, 85.18it/s]
# convert examples to features: 160it [00:01, 80.06it/s]
# convert examples to features: 169it [00:02, 71.89it/s]
# convert examples to features: 177it [00:02, 72.94it/s]
# convert examples to features: 185it [00:02, 67.25it/s]
# convert examples to features: 193it [00:02, 67.69it/s]
# convert examples to features: 200it [00:02, 66.81it/s]
# convert examples to features: 207it [00:02, 64.36it/s]
# convert examples to features: 214it [00:02, 63.66it/s]
# convert examples to features: 221it [00:02, 63.87it/s]
# convert examples to features: 228it [00:02, 64.49it/s]
# convert examples to features: 235it [00:03, 58.20it/s]
# convert examples to features: 241it [00:03, 56.68it/s]
# convert examples to features: 248it [00:03, 58.71it/s]
# convert examples to features: 261it [00:03, 69.73it/s]
# convert examples to features: 273it [00:03, 78.52it/s]
# convert examples to features: 282it [00:03, 77.92it/s]
# convert examples to features: 291it [00:04, 47.78it/s]
# convert examples to features: 298it [00:04, 30.28it/s]
# convert examples to features: 304it [00:04, 30.50it/s]
# convert examples to features: 309it [00:04, 26.10it/s]
# convert examples to features: 313it [00:05, 22.65it/s]
# convert examples to features: 317it [00:05, 24.21it/s]
# convert examples to features: 321it [00:05, 26.54it/s]
# convert examples to features: 325it [00:05, 28.57it/s]
# convert examples to features: 329it [00:05, 30.31it/s]
# convert examples to features: 333it [00:05, 25.24it/s]
# convert examples to features: 336it [00:06, 21.73it/s]
# convert examples to features: 339it [00:06, 20.90it/s]
# convert examples to features: 342it [00:06, 21.95it/s]
# convert examples to features: 345it [00:06, 23.51it/s]
# convert examples to features: 348it [00:06, 23.49it/s]
# convert examples to features: 351it [00:06, 24.84it/s]
# convert examples to features: 354it [00:06, 25.86it/s]
# convert examples to features: 357it [00:06, 26.13it/s]
# convert examples to features: 360it [00:07, 23.71it/s]
# convert examples to features: 363it [00:07, 22.32it/s]
# convert examples to features: 366it [00:07, 21.27it/s]
# convert examples to features: 369it [00:07, 16.69it/s]
# convert examples to features: 371it [00:07, 10.97it/s]
# convert examples to features: 373it [00:08,  8.66it/s]
# convert examples to features: 375it [00:08,  7.71it/s]
# convert examples to features: 377it [00:08,  7.02it/s]
# convert examples to features: 378it [00:09,  6.63it/s]
# convert examples to features: 379it [00:09,  6.41it/s]
# convert examples to features: 380it [00:09,  6.25it/s]
# convert examples to features: 381it [00:09,  6.16it/s]
# convert examples to features: 382it [00:09,  6.07it/s]
# convert examples to features: 383it [00:10,  4.81it/s]
# convert examples to features: 384it [00:10,  4.19it/s]
# convert examples to features: 385it [00:10,  3.84it/s]
# convert examples to features: 386it [00:11,  3.63it/s]
# convert examples to features: 387it [00:11,  3.49it/s]
# convert examples to features: 388it [00:11,  3.42it/s]
# convert examples to features: 389it [00:11,  3.36it/s]
# convert examples to features: 390it [00:12,  3.32it/s]
# convert examples to features: 391it [00:12,  3.23it/s]
# convert examples to features: 392it [00:12,  3.22it/s]
# convert examples to features: 393it [00:13,  3.19it/s]
# convert examples to features: 394it [00:13,  3.17it/s]
# convert examples to features: 395it [00:13,  3.16it/s]
# convert examples to features: 396it [00:14,  3.16it/s]
# convert examples to features: 397it [00:14,  3.15it/s]
# convert examples to features: 398it [00:14,  3.14it/s]
# convert examples to features: 399it [00:15,  3.13it/s]
# convert examples to features: 400it [00:15,  3.13it/s]
# convert examples to features: 401it [00:15,  3.13it/s]
# convert examples to features: 402it [00:16,  3.14it/s]
# convert examples to features: 403it [00:16,  3.14it/s]
# convert examples to features: 404it [00:16,  3.13it/s]
# convert examples to features: 405it [00:17,  3.13it/s]
# convert examples to features: 406it [00:17,  3.07it/s]
# convert examples to features: 407it [00:17,  3.09it/s]
# convert examples to features: 408it [00:18,  3.11it/s]
# convert examples to features: 411it [00:18,  4.24it/s]
# convert examples to features: 414it [00:18,  5.71it/s]
# convert examples to features: 417it [00:18,  7.52it/s]
# convert examples to features: 420it [00:18,  9.32it/s]
# convert examples to features: 423it [00:18, 10.62it/s]
# convert examples to features: 425it [00:18, 11.73it/s]
# convert examples to features: 427it [00:18, 12.64it/s]
# convert examples to features: 429it [00:19, 13.40it/s]
# convert examples to features: 431it [00:19, 13.85it/s]
# convert examples to features: 433it [00:19, 14.36it/s]
# convert examples to features: 436it [00:19, 16.28it/s]
# convert examples to features: 440it [00:19, 19.13it/s]
# convert examples to features: 444it [00:19, 21.76it/s]
# convert examples to features: 451it [00:19, 27.37it/s]
# convert examples to features: 460it [00:19, 34.57it/s]
# convert examples to features: 468it [00:20, 41.19it/s]
# convert examples to features: 475it [00:20, 45.33it/s]
# convert examples to features: 481it [00:20, 37.02it/s]
# convert examples to features: 486it [00:20, 31.88it/s]
# convert examples to features: 491it [00:20, 29.51it/s]
# convert examples to features: 499it [00:20, 36.13it/s]
# convert examples to features: 507it [00:20, 42.33it/s]
# convert examples to features: 513it [00:21, 46.09it/s]
# convert examples to features: 519it [00:21, 48.72it/s]
# convert examples to features: 525it [00:22, 14.22it/s]
# convert examples to features: 530it [00:23,  8.65it/s]
# convert examples to features: 533it [00:24,  6.82it/s]
# convert examples to features: 536it [00:24,  5.93it/s]
# convert examples to features: 538it [00:24,  6.51it/s]
# convert examples to features: 548it [00:25,  9.04it/s]
# convert examples to features: 556it [00:25, 12.27it/s]
# convert examples to features: 564it [00:25, 22.15it/s]
#
# convert examples to features: 0it [00:00, ?it/s]
# convert examples to features: 13it [00:00, 121.33it/s]
# convert examples to features: 23it [00:00, 112.44it/s]
# convert examples to features: 32it [00:00, 103.23it/s]
# convert examples to features: 41it [00:00, 98.60it/s]
# convert examples to features: 52it [00:00, 101.08it/s]
# convert examples to features: 61it [00:00, 96.86it/s]
# convert examples to features: 77it [00:00, 108.37it/s]
# convert examples to features: 88it [00:00, 99.38it/s]
# convert examples to features: 98it [00:00, 95.39it/s]
# convert examples to features: 108it [00:01, 89.43it/s]
# convert examples to features: 118it [00:01, 91.28it/s]
# convert examples to features: 128it [00:01, 84.80it/s]
# convert examples to features: 137it [00:01, 78.27it/s]
# convert examples to features: 151it [00:01, 89.89it/s]
# convert examples to features: 161it [00:01, 81.63it/s]
# convert examples to features: 170it [00:01, 73.57it/s]
# convert examples to features: 178it [00:01, 72.99it/s]
# convert examples to features: 186it [00:02, 66.10it/s]
# convert examples to features: 194it [00:02, 64.98it/s]
# convert examples to features: 201it [00:02, 65.67it/s]
# convert examples to features: 208it [00:02, 63.69it/s]
# convert examples to features: 215it [00:02, 63.13it/s]
# convert examples to features: 222it [00:02, 63.31it/s]
# convert examples to features: 229it [00:02, 64.21it/s]
# convert examples to features: 236it [00:02, 57.77it/s]
# convert examples to features: 242it [00:03, 56.46it/s]
# convert examples to features: 248it [00:03, 56.35it/s]
# convert examples to features: 258it [00:03, 64.71it/s]
# convert examples to features: 271it [00:03, 75.85it/s]
# convert examples to features: 280it [00:03, 75.65it/s]
# convert examples to features: 289it [00:03, 57.90it/s]
# convert examples to features: 296it [00:04, 29.50it/s]
# convert examples to features: 302it [00:04, 29.93it/s]
# convert examples to features: 307it [00:04, 28.48it/s]
# convert examples to features: 312it [00:04, 22.85it/s]
# convert examples to features: 316it [00:05, 23.88it/s]
# convert examples to features: 320it [00:05, 25.93it/s]
# convert examples to features: 324it [00:05, 27.93it/s]
# convert examples to features: 328it [00:05, 29.78it/s]
# convert examples to features: 332it [00:05, 26.78it/s]
# convert examples to features: 335it [00:05, 22.29it/s]
# convert examples to features: 338it [00:06, 20.00it/s]
# convert examples to features: 341it [00:06, 22.11it/s]
# convert examples to features: 344it [00:06, 23.63it/s]
# convert examples to features: 347it [00:06, 24.89it/s]
# convert examples to features: 350it [00:06, 25.63it/s]
# convert examples to features: 353it [00:06, 26.40it/s]
# convert examples to features: 357it [00:06, 26.75it/s]
# convert examples to features: 360it [00:06, 24.07it/s]
# convert examples to features: 363it [00:07, 22.38it/s]
# convert examples to features: 366it [00:07, 21.20it/s]
# convert examples to features: 369it [00:07, 16.69it/s]
# convert examples to features: 371it [00:07, 10.95it/s]
# convert examples to features: 373it [00:08,  8.83it/s]
# convert examples to features: 375it [00:08,  7.76it/s]
# convert examples to features: 377it [00:08,  7.16it/s]
# convert examples to features: 378it [00:08,  6.75it/s]
# convert examples to features: 379it [00:09,  6.49it/s]
# convert examples to features: 380it [00:09,  6.32it/s]
# convert examples to features: 381it [00:09,  6.19it/s]
# convert examples to features: 382it [00:09,  6.11it/s]
# convert examples to features: 383it [00:09,  4.82it/s]
# convert examples to features: 384it [00:10,  4.20it/s]
# convert examples to features: 385it [00:10,  3.83it/s]
# convert examples to features: 386it [00:10,  3.61it/s]
# convert examples to features: 387it [00:11,  3.49it/s]
# convert examples to features: 388it [00:11,  3.42it/s]
# convert examples to features: 389it [00:11,  3.35it/s]
# convert examples to features: 390it [00:12,  3.31it/s]
# convert examples to features: 391it [00:12,  3.28it/s]
# convert examples to features: 392it [00:12,  3.26it/s]
# convert examples to features: 393it [00:13,  3.22it/s]
# convert examples to features: 394it [00:13,  3.19it/s]
# convert examples to features: 395it [00:13,  3.18it/s]
# convert examples to features: 396it [00:13,  3.17it/s]
# convert examples to features: 397it [00:14,  3.16it/s]
# convert examples to features: 398it [00:14,  3.16it/s]
# convert examples to features: 399it [00:14,  3.13it/s]
# convert examples to features: 400it [00:15,  3.12it/s]
# convert examples to features: 401it [00:15,  3.12it/s]
# convert examples to features: 402it [00:15,  3.12it/s]
# convert examples to features: 403it [00:16,  3.12it/s]
# convert examples to features: 404it [00:16,  3.11it/s]
# convert examples to features: 405it [00:16,  3.12it/s]
# convert examples to features: 406it [00:17,  3.13it/s]
# convert examples to features: 407it [00:17,  3.13it/s]
# convert examples to features: 408it [00:17,  3.14it/s]
# convert examples to features: 411it [00:17,  4.29it/s]
# convert examples to features: 414it [00:18,  5.77it/s]
# convert examples to features: 417it [00:18,  7.58it/s]
# convert examples to features: 420it [00:18,  9.48it/s]
# convert examples to features: 423it [00:18, 10.77it/s]
# convert examples to features: 425it [00:18, 11.80it/s]
# convert examples to features: 427it [00:18, 12.70it/s]
# convert examples to features: 429it [00:18, 13.46it/s]
# convert examples to features: 431it [00:18, 13.41it/s]
# convert examples to features: 433it [00:19, 13.98it/s]
# convert examples to features: 436it [00:19, 15.95it/s]
# convert examples to features: 440it [00:19, 18.81it/s]
# convert examples to features: 444it [00:19, 21.42it/s]
# convert examples to features: 451it [00:19, 27.05it/s]
# convert examples to features: 460it [00:19, 34.15it/s]
# convert examples to features: 468it [00:19, 40.93it/s]
# convert examples to features: 475it [00:19, 45.03it/s]
# convert examples to features: 481it [00:20, 36.86it/s]
# convert examples to features: 486it [00:20, 32.52it/s]
# convert examples to features: 491it [00:20, 30.07it/s]
# convert examples to features: 499it [00:20, 36.62it/s]
# convert examples to features: 506it [00:20, 41.82it/s]
# convert examples to features: 512it [00:20, 45.71it/s]
# convert examples to features: 518it [00:20, 48.75it/s]
# convert examples to features: 524it [00:21, 16.65it/s]
# convert examples to features: 529it [00:22,  9.27it/s]
# convert examples to features: 532it [00:23,  7.06it/s]
# convert examples to features: 535it [00:24,  6.06it/s]
# convert examples to features: 537it [00:24,  5.49it/s]
# convert examples to features: 547it [00:24,  7.65it/s]
# convert examples to features: 555it [00:24, 10.48it/s]
# convert examples to features: 564it [00:25, 22.32it/s]
# Epoch:  68%|██████▊   | 34/50 [1:22:03<38:25, 144.07s/it]
# convert examples to features: 0it [00:00, ?it/s]
# convert examples to features: 13it [00:00, 121.14it/s]
# convert examples to features: 23it [00:00, 112.50it/s]
# convert examples to features: 32it [00:00, 102.57it/s]
# convert examples to features: 42it [00:00, 98.93it/s]
# convert examples to features: 53it [00:00, 100.69it/s]
# convert examples to features: 64it [00:00, 102.14it/s]
# convert examples to features: 79it [00:00, 111.35it/s]
# convert examples to features: 90it [00:00, 101.28it/s]
# convert examples to features: 100it [00:00, 94.45it/s]
# convert examples to features: 110it [00:01, 89.15it/s]
# convert examples to features: 120it [00:01, 91.10it/s]
# convert examples to features: 130it [00:01, 83.89it/s]
# convert examples to features: 139it [00:01, 81.73it/s]
# convert examples to features: 150it [00:01, 87.70it/s]
# convert examples to features: 159it [00:01, 81.84it/s]
# convert examples to features: 168it [00:01, 73.27it/s]
# convert examples to features: 176it [00:01, 73.48it/s]
# convert examples to features: 184it [00:02, 68.05it/s]
# convert examples to features: 192it [00:02, 68.90it/s]
# convert examples to features: 200it [00:02, 67.30it/s]
# convert examples to features: 207it [00:02, 61.00it/s]
# convert examples to features: 214it [00:02, 61.16it/s]
# convert examples to features: 221it [00:02, 61.86it/s]
# convert examples to features: 228it [00:02, 62.96it/s]
# convert examples to features: 235it [00:02, 57.21it/s]
# convert examples to features: 241it [00:03, 56.00it/s]
# convert examples to features: 248it [00:03, 58.19it/s]
# convert examples to features: 261it [00:03, 69.16it/s]
# convert examples to features: 273it [00:03, 78.22it/s]
# convert examples to features: 282it [00:03, 75.65it/s]
# convert examples to features: 291it [00:03, 47.33it/s]
# convert examples to features: 298it [00:04, 30.14it/s]
# convert examples to features: 304it [00:04, 30.44it/s]
# convert examples to features: 309it [00:04, 25.95it/s]
# convert examples to features: 313it [00:05, 22.55it/s]
# convert examples to features: 317it [00:05, 24.02it/s]
# convert examples to features: 321it [00:05, 26.39it/s]
# convert examples to features: 325it [00:05, 27.72it/s]
# convert examples to features: 329it [00:05, 29.55it/s]
# convert examples to features: 333it [00:05, 25.02it/s]
# convert examples to features: 336it [00:05, 21.47it/s]
# convert examples to features: 339it [00:06, 20.68it/s]
# convert examples to features: 342it [00:06, 22.70it/s]
# convert examples to features: 345it [00:06, 24.09it/s]
# convert examples to features: 348it [00:06, 24.21it/s]
# convert examples to features: 351it [00:06, 25.25it/s]
# convert examples to features: 354it [00:06, 26.22it/s]
# convert examples to features: 357it [00:06, 26.32it/s]
# convert examples to features: 360it [00:06, 23.85it/s]
# convert examples to features: 363it [00:07, 22.26it/s]
# convert examples to features: 366it [00:07, 21.26it/s]
# convert examples to features: 369it [00:07, 16.74it/s]
# convert examples to features: 371it [00:07, 10.91it/s]
# convert examples to features: 373it [00:08,  8.80it/s]
# convert examples to features: 375it [00:08,  7.75it/s]
# convert examples to features: 377it [00:08,  7.14it/s]
# convert examples to features: 378it [00:08,  6.72it/s]
# convert examples to features: 379it [00:09,  6.47it/s]
# convert examples to features: 380it [00:09,  6.29it/s]
# convert examples to features: 381it [00:09,  6.19it/s]
# convert examples to features: 382it [00:09,  6.12it/s]
# convert examples to features: 383it [00:09,  4.84it/s]
# convert examples to features: 384it [00:10,  4.22it/s]
# convert examples to features: 385it [00:10,  3.87it/s]
# convert examples to features: 386it [00:10,  3.64it/s]
# convert examples to features: 387it [00:11,  3.50it/s]
# convert examples to features: 388it [00:11,  3.41it/s]
# convert examples to features: 389it [00:11,  3.36it/s]
# convert examples to features: 390it [00:12,  3.31it/s]
# convert examples to features: 391it [00:12,  3.29it/s]
# convert examples to features: 392it [00:12,  3.27it/s]
# convert examples to features: 393it [00:13,  3.24it/s]
# convert examples to features: 394it [00:13,  3.22it/s]
# convert examples to features: 395it [00:13,  3.20it/s]
# convert examples to features: 396it [00:13,  3.17it/s]
# convert examples to features: 397it [00:14,  3.15it/s]
# convert examples to features: 398it [00:14,  3.10it/s]
# convert examples to features: 399it [00:14,  3.11it/s]
# convert examples to features: 400it [00:15,  3.12it/s]
# convert examples to features: 401it [00:15,  3.13it/s]
# convert examples to features: 402it [00:15,  3.12it/s]
# convert examples to features: 403it [00:16,  3.13it/s]
# convert examples to features: 404it [00:16,  3.13it/s]
# convert examples to features: 405it [00:16,  3.12it/s]
# convert examples to features: 406it [00:17,  3.12it/s]
# convert examples to features: 407it [00:17,  3.13it/s]
# convert examples to features: 408it [00:17,  3.12it/s]
# convert examples to features: 411it [00:17,  4.26it/s]
# convert examples to features: 414it [00:18,  5.74it/s]
# convert examples to features: 417it [00:18,  7.47it/s]
# convert examples to features: 420it [00:18,  9.26it/s]
# convert examples to features: 422it [00:18, 10.52it/s]
# convert examples to features: 424it [00:18, 11.64it/s]
# convert examples to features: 426it [00:18, 12.55it/s]
# convert examples to features: 428it [00:18, 13.31it/s]
# convert examples to features: 430it [00:18, 13.80it/s]
# convert examples to features: 432it [00:19, 14.25it/s]
# convert examples to features: 434it [00:19, 14.65it/s]
# convert examples to features: 438it [00:19, 17.57it/s]
# convert examples to features: 442it [00:19, 20.30it/s]
# convert examples to features: 445it [00:19, 22.18it/s]
# convert examples to features: 452it [00:19, 27.64it/s]
# convert examples to features: 461it [00:19, 34.71it/s]
# convert examples to features: 469it [00:19, 41.49it/s]
# convert examples to features: 475it [00:19, 45.18it/s]
# convert examples to features: 481it [00:20, 36.81it/s]
# convert examples to features: 486it [00:20, 32.56it/s]
# convert examples to features: 491it [00:20, 30.15it/s]
# convert examples to features: 499it [00:20, 36.80it/s]
# convert examples to features: 507it [00:20, 42.98it/s]
# convert examples to features: 513it [00:20, 46.73it/s]
# convert examples to features: 519it [00:21, 49.29it/s]
# convert examples to features: 525it [00:22, 14.24it/s]
# convert examples to features: 530it [00:23,  8.73it/s]
# convert examples to features: 534it [00:24,  6.85it/s]
# convert examples to features: 537it [00:24,  5.87it/s]
# convert examples to features: 547it [00:24,  8.18it/s]
# convert examples to features: 555it [00:25, 11.17it/s]
# convert examples to features: 564it [00:25, 22.28it/s]
#
# convert examples to features: 0it [00:00, ?it/s]
# convert examples to features: 13it [00:00, 118.98it/s]
# convert examples to features: 23it [00:00, 111.24it/s]
# convert examples to features: 33it [00:00, 107.54it/s]
# convert examples to features: 43it [00:00, 102.06it/s]
# convert examples to features: 54it [00:00, 102.18it/s]
# convert examples to features: 66it [00:00, 106.20it/s]
# convert examples to features: 79it [00:00, 111.98it/s]
# convert examples to features: 90it [00:00, 101.05it/s]
# convert examples to features: 100it [00:00, 94.73it/s]
# convert examples to features: 110it [00:01, 88.57it/s]
# convert examples to features: 120it [00:01, 90.35it/s]
# convert examples to features: 130it [00:01, 80.80it/s]
# convert examples to features: 139it [00:01, 79.34it/s]
# convert examples to features: 152it [00:01, 88.62it/s]
# convert examples to features: 162it [00:01, 80.05it/s]
# convert examples to features: 171it [00:01, 70.38it/s]
# convert examples to features: 179it [00:02, 69.88it/s]
# convert examples to features: 187it [00:02, 67.63it/s]
# convert examples to features: 195it [00:02, 63.47it/s]
# convert examples to features: 202it [00:02, 61.61it/s]
# convert examples to features: 209it [00:02, 61.31it/s]
# convert examples to features: 216it [00:02, 61.36it/s]
# convert examples to features: 223it [00:02, 62.07it/s]
# convert examples to features: 230it [00:02, 62.08it/s]
# convert examples to features: 237it [00:03, 57.27it/s]
# convert examples to features: 243it [00:03, 55.77it/s]
# convert examples to features: 251it [00:03, 60.93it/s]
# convert examples to features: 265it [00:03, 72.97it/s]
# convert examples to features: 275it [00:03, 78.43it/s]
# convert examples to features: 284it [00:03, 77.30it/s]
# convert examples to features: 293it [00:04, 40.35it/s]
# convert examples to features: 300it [00:04, 30.93it/s]
# convert examples to features: 306it [00:04, 30.97it/s]
# convert examples to features: 311it [00:04, 23.97it/s]
# convert examples to features: 315it [00:05, 23.51it/s]
# convert examples to features: 319it [00:05, 25.48it/s]
# convert examples to features: 323it [00:05, 27.53it/s]
# convert examples to features: 327it [00:05, 28.51it/s]
# convert examples to features: 331it [00:05, 27.95it/s]
# convert examples to features: 335it [00:05, 22.90it/s]
# convert examples to features: 338it [00:06, 20.49it/s]
# convert examples to features: 341it [00:06, 22.52it/s]
# convert examples to features: 344it [00:06, 23.96it/s]
# convert examples to features: 347it [00:06, 25.15it/s]
# convert examples to features: 350it [00:06, 25.88it/s]
# convert examples to features: 353it [00:06, 25.62it/s]
# convert examples to features: 357it [00:06, 26.18it/s]
# convert examples to features: 360it [00:06, 23.82it/s]
# convert examples to features: 363it [00:07, 22.29it/s]
# convert examples to features: 366it [00:07, 21.27it/s]
# convert examples to features: 369it [00:07, 16.75it/s]
# convert examples to features: 371it [00:07, 10.92it/s]
# convert examples to features: 373it [00:08,  8.80it/s]
# convert examples to features: 375it [00:08,  7.67it/s]
# convert examples to features: 377it [00:08,  7.10it/s]
# convert examples to features: 378it [00:08,  6.71it/s]
# convert examples to features: 379it [00:09,  6.44it/s]
# convert examples to features: 380it [00:09,  6.28it/s]
# convert examples to features: 381it [00:09,  6.16it/s]
# convert examples to features: 382it [00:09,  6.07it/s]
# convert examples to features: 383it [00:09,  4.83it/s]
# convert examples to features: 384it [00:10,  4.21it/s]
# convert examples to features: 385it [00:10,  3.86it/s]
# convert examples to features: 386it [00:10,  3.65it/s]
# convert examples to features: 387it [00:11,  3.51it/s]
# convert examples to features: 388it [00:11,  3.43it/s]
# convert examples to features: 389it [00:11,  3.36it/s]
# convert examples to features: 390it [00:12,  3.32it/s]
# convert examples to features: 391it [00:12,  3.29it/s]
# convert examples to features: 392it [00:12,  3.28it/s]
# convert examples to features: 393it [00:13,  3.24it/s]
# convert examples to features: 394it [00:13,  3.15it/s]
# convert examples to features: 395it [00:13,  3.11it/s]
# convert examples to features: 396it [00:14,  3.12it/s]
# convert examples to features: 397it [00:14,  3.12it/s]
# convert examples to features: 398it [00:14,  3.07it/s]
# convert examples to features: 399it [00:15,  3.09it/s]
# convert examples to features: 400it [00:15,  3.09it/s]
# convert examples to features: 401it [00:15,  3.10it/s]
# convert examples to features: 402it [00:15,  3.11it/s]
# convert examples to features: 403it [00:16,  3.11it/s]
# convert examples to features: 404it [00:16,  3.11it/s]
# convert examples to features: 405it [00:16,  3.11it/s]
# convert examples to features: 406it [00:17,  3.11it/s]
# convert examples to features: 407it [00:17,  3.11it/s]
# convert examples to features: 408it [00:17,  3.11it/s]
# convert examples to features: 411it [00:17,  4.26it/s]
# convert examples to features: 414it [00:18,  5.73it/s]
# convert examples to features: 417it [00:18,  7.53it/s]
# convert examples to features: 420it [00:18,  9.43it/s]
# convert examples to features: 423it [00:18, 10.71it/s]
# convert examples to features: 425it [00:18, 11.81it/s]
# convert examples to features: 427it [00:18, 12.72it/s]
# convert examples to features: 429it [00:18, 13.48it/s]
# convert examples to features: 431it [00:19, 13.92it/s]
# convert examples to features: 433it [00:19, 14.32it/s]
# convert examples to features: 436it [00:19, 16.30it/s]
# convert examples to features: 440it [00:19, 19.15it/s]
# convert examples to features: 444it [00:19, 21.69it/s]
# convert examples to features: 452it [00:19, 27.55it/s]
# convert examples to features: 461it [00:19, 34.55it/s]
# convert examples to features: 469it [00:19, 41.21it/s]
# convert examples to features: 475it [00:19, 44.86it/s]
# convert examples to features: 481it [00:20, 36.80it/s]
# convert examples to features: 486it [00:20, 32.49it/s]
# convert examples to features: 491it [00:20, 30.15it/s]
# convert examples to features: 499it [00:20, 36.78it/s]
# convert examples to features: 507it [00:20, 42.86it/s]
# convert examples to features: 513it [00:20, 46.58it/s]
# convert examples to features: 519it [00:21, 49.34it/s]
# convert examples to features: 525it [00:22, 14.03it/s]
# convert examples to features: 530it [00:23,  8.68it/s]
# convert examples to features: 534it [00:24,  6.78it/s]
# convert examples to features: 537it [00:24,  5.84it/s]
# convert examples to features: 548it [00:24,  8.14it/s]
# convert examples to features: 556it [00:25, 11.13it/s]
# convert examples to features: 564it [00:25, 22.27it/s]
# Epoch:  70%|███████   | 35/50 [1:24:17<35:13, 140.92s/it]
# ...
# convert examples to features: 427it [00:18, 12.66it/s]
# convert examples to features: 429it [00:18, 12.89it/s]
# convert examples to features: 431it [00:19, 13.39it/s]
# convert examples to features: 433it [00:19, 13.97it/s]
# convert examples to features: 435it [00:19, 14.83it/s]
# convert examples to features: 438it [00:19, 17.30it/s]
# convert examples to features: 442it [00:19, 20.04it/s]
# convert examples to features: 446it [00:19, 23.38it/s]
# convert examples to features: 456it [00:19, 30.16it/s]
# convert examples to features: 464it [00:19, 36.92it/s]
# convert examples to features: 472it [00:19, 43.48it/s]
# convert examples to features: 479it [00:20, 39.28it/s]
# convert examples to features: 485it [00:20, 33.91it/s]
# convert examples to features: 490it [00:20, 30.97it/s]
# convert examples to features: 495it [00:20, 34.31it/s]
# convert examples to features: 504it [00:20, 42.07it/s]
# convert examples to features: 510it [00:20, 45.69it/s]
# convert examples to features: 516it [00:21, 48.82it/s]
# convert examples to features: 522it [00:21, 24.95it/s]
# convert examples to features: 527it [00:22, 10.70it/s]
# convert examples to features: 531it [00:23,  7.56it/s]
# convert examples to features: 534it [00:24,  6.32it/s]
# convert examples to features: 536it [00:24,  5.64it/s]
# convert examples to features: 538it [00:24,  6.24it/s]
# convert examples to features: 548it [00:24,  8.67it/s]
# convert examples to features: 556it [00:25, 11.81it/s]
# convert examples to features: 564it [00:25, 22.22it/s]
# Epoch:  98%|█████████▊| 49/50 [1:58:16<02:27, 147.11s/it]
# convert examples to features: 0it [00:00, ?it/s]
# convert examples to features: 12it [00:00, 119.79it/s]
# convert examples to features: 22it [00:00, 110.43it/s]
# convert examples to features: 33it [00:00, 107.76it/s]
# convert examples to features: 42it [00:00, 101.22it/s]
# convert examples to features: 53it [00:00, 101.80it/s]
# convert examples to features: 64it [00:00, 102.65it/s]
# convert examples to features: 79it [00:00, 111.91it/s]
# convert examples to features: 90it [00:00, 101.08it/s]
# convert examples to features: 100it [00:00, 94.46it/s]
# convert examples to features: 110it [00:01, 89.28it/s]
# convert examples to features: 120it [00:01, 91.17it/s]
# convert examples to features: 130it [00:01, 83.89it/s]
# convert examples to features: 139it [00:01, 81.83it/s]
# convert examples to features: 152it [00:01, 90.11it/s]
# convert examples to features: 162it [00:01, 81.53it/s]
# convert examples to features: 171it [00:01, 73.86it/s]
# convert examples to features: 179it [00:02, 71.99it/s]
# convert examples to features: 187it [00:02, 68.69it/s]
# convert examples to features: 195it [00:02, 66.57it/s]
# convert examples to features: 202it [00:02, 66.00it/s]
# convert examples to features: 209it [00:02, 63.91it/s]
# convert examples to features: 216it [00:02, 62.21it/s]
# convert examples to features: 223it [00:02, 62.62it/s]
# convert examples to features: 230it [00:02, 61.99it/s]
# convert examples to features: 237it [00:02, 56.83it/s]
# convert examples to features: 243it [00:03, 55.47it/s]
# convert examples to features: 251it [00:03, 60.72it/s]
# convert examples to features: 265it [00:03, 72.86it/s]
# convert examples to features: 275it [00:03, 77.88it/s]
# convert examples to features: 284it [00:03, 76.69it/s]
# convert examples to features: 293it [00:04, 40.21it/s]
# convert examples to features: 300it [00:04, 31.10it/s]
# convert examples to features: 306it [00:04, 30.98it/s]
# convert examples to features: 311it [00:04, 24.04it/s]
# convert examples to features: 315it [00:05, 23.65it/s]
# convert examples to features: 319it [00:05, 25.86it/s]
# convert examples to features: 323it [00:05, 27.90it/s]
# convert examples to features: 327it [00:05, 29.68it/s]
# convert examples to features: 331it [00:05, 28.86it/s]
# convert examples to features: 335it [00:05, 23.34it/s]
# convert examples to features: 338it [00:05, 20.74it/s]
# convert examples to features: 341it [00:06, 22.62it/s]
# convert examples to features: 344it [00:06, 24.07it/s]
# convert examples to features: 347it [00:06, 25.31it/s]
# convert examples to features: 350it [00:06, 26.15it/s]
# convert examples to features: 353it [00:06, 26.61it/s]
# convert examples to features: 357it [00:06, 26.93it/s]
# convert examples to features: 360it [00:06, 24.22it/s]
# convert examples to features: 363it [00:06, 22.59it/s]
# convert examples to features: 366it [00:07, 21.37it/s]
# convert examples to features: 369it [00:07, 16.81it/s]
# convert examples to features: 371it [00:07, 10.98it/s]
# convert examples to features: 373it [00:08,  8.84it/s]
# convert examples to features: 375it [00:08,  7.78it/s]
# convert examples to features: 377it [00:08,  7.16it/s]
# convert examples to features: 378it [00:08,  6.76it/s]
# convert examples to features: 379it [00:09,  6.51it/s]
# convert examples to features: 380it [00:09,  6.34it/s]
# convert examples to features: 381it [00:09,  6.18it/s]
# convert examples to features: 382it [00:09,  6.10it/s]
# convert examples to features: 383it [00:09,  4.69it/s]
# convert examples to features: 384it [00:10,  4.13it/s]
# convert examples to features: 385it [00:10,  3.81it/s]
# convert examples to features: 386it [00:10,  3.62it/s]
# convert examples to features: 387it [00:11,  3.49it/s]
# convert examples to features: 388it [00:11,  3.40it/s]
# convert examples to features: 389it [00:11,  3.34it/s]
# convert examples to features: 390it [00:12,  3.30it/s]
# convert examples to features: 391it [00:12,  3.28it/s]
# convert examples to features: 392it [00:12,  3.27it/s]
# convert examples to features: 393it [00:12,  3.22it/s]
# convert examples to features: 394it [00:13,  3.19it/s]
# convert examples to features: 395it [00:13,  3.17it/s]
# convert examples to features: 396it [00:13,  3.15it/s]
# convert examples to features: 397it [00:14,  3.13it/s]
# convert examples to features: 398it [00:14,  3.11it/s]
# convert examples to features: 399it [00:14,  3.12it/s]
# convert examples to features: 400it [00:15,  3.11it/s]
# convert examples to features: 401it [00:15,  3.11it/s]
# convert examples to features: 402it [00:15,  3.10it/s]
# convert examples to features: 403it [00:16,  3.11it/s]
# convert examples to features: 404it [00:16,  3.12it/s]
# convert examples to features: 405it [00:16,  3.12it/s]
# convert examples to features: 406it [00:17,  3.09it/s]
# convert examples to features: 407it [00:17,  3.10it/s]
# convert examples to features: 408it [00:17,  3.11it/s]
# convert examples to features: 411it [00:17,  4.25it/s]
# convert examples to features: 414it [00:18,  5.72it/s]
# convert examples to features: 417it [00:18,  7.54it/s]
# convert examples to features: 420it [00:18,  9.30it/s]
# convert examples to features: 423it [00:18, 10.60it/s]
# convert examples to features: 425it [00:18, 11.72it/s]
# convert examples to features: 427it [00:18, 12.62it/s]
# convert examples to features: 429it [00:18, 13.38it/s]
# convert examples to features: 431it [00:18, 13.84it/s]
# convert examples to features: 433it [00:19, 14.25it/s]
# convert examples to features: 436it [00:19, 16.24it/s]
# convert examples to features: 440it [00:19, 19.07it/s]
# convert examples to features: 444it [00:19, 21.63it/s]
# convert examples to features: 451it [00:19, 27.27it/s]
# convert examples to features: 459it [00:19, 33.72it/s]
# convert examples to features: 467it [00:19, 40.51it/s]
# convert examples to features: 475it [00:19, 45.14it/s]
# convert examples to features: 481it [00:20, 36.71it/s]
# convert examples to features: 486it [00:20, 32.47it/s]
# convert examples to features: 491it [00:20, 30.18it/s]
# convert examples to features: 499it [00:20, 36.75it/s]
# convert examples to features: 506it [00:20, 41.74it/s]
# convert examples to features: 512it [00:20, 45.48it/s]
# convert examples to features: 518it [00:20, 48.55it/s]
# convert examples to features: 524it [00:21, 16.41it/s]
# convert examples to features: 529it [00:22,  9.22it/s]
# convert examples to features: 532it [00:23,  7.04it/s]
# convert examples to features: 535it [00:24,  6.05it/s]
# convert examples to features: 537it [00:24,  5.48it/s]
# convert examples to features: 547it [00:24,  7.65it/s]
# convert examples to features: 555it [00:24, 10.48it/s]
# convert examples to features: 564it [00:25, 22.33it/s]
#
# convert examples to features: 0it [00:00, ?it/s]
# convert examples to features: 13it [00:00, 118.72it/s]
# convert examples to features: 22it [00:00, 104.74it/s]
# convert examples to features: 33it [00:00, 104.30it/s]
# convert examples to features: 43it [00:00, 99.87it/s]
# convert examples to features: 54it [00:00, 100.30it/s]
# convert examples to features: 65it [00:00, 102.64it/s]
# convert examples to features: 79it [00:00, 110.98it/s]
# convert examples to features: 90it [00:00, 100.94it/s]
# convert examples to features: 100it [00:01, 94.48it/s]
# convert examples to features: 110it [00:01, 88.93it/s]
# convert examples to features: 120it [00:01, 90.45it/s]
# convert examples to features: 130it [00:01, 84.02it/s]
# convert examples to features: 139it [00:01, 82.48it/s]
# convert examples to features: 152it [00:01, 91.94it/s]
# convert examples to features: 162it [00:01, 82.02it/s]
# convert examples to features: 171it [00:01, 74.99it/s]
# convert examples to features: 179it [00:02, 73.11it/s]
# convert examples to features: 187it [00:02, 69.48it/s]
# convert examples to features: 195it [00:02, 67.10it/s]
# convert examples to features: 202it [00:02, 66.69it/s]
# convert examples to features: 209it [00:02, 64.89it/s]
# convert examples to features: 216it [00:02, 63.85it/s]
# convert examples to features: 223it [00:02, 63.88it/s]
# convert examples to features: 230it [00:02, 60.90it/s]
# convert examples to features: 237it [00:03, 53.55it/s]
# convert examples to features: 243it [00:03, 53.66it/s]
# convert examples to features: 251it [00:03, 59.28it/s]
# convert examples to features: 262it [00:03, 68.16it/s]
# convert examples to features: 274it [00:03, 76.60it/s]
# convert examples to features: 283it [00:03, 76.48it/s]
# convert examples to features: 292it [00:03, 42.43it/s]
# convert examples to features: 299it [00:04, 30.24it/s]
# convert examples to features: 305it [00:04, 30.42it/s]
# convert examples to features: 310it [00:04, 24.76it/s]
# convert examples to features: 314it [00:05, 23.05it/s]
# convert examples to features: 318it [00:05, 24.84it/s]
# convert examples to features: 322it [00:05, 26.62it/s]
# convert examples to features: 326it [00:05, 28.74it/s]
# convert examples to features: 330it [00:05, 30.31it/s]
# convert examples to features: 334it [00:05, 23.75it/s]
# convert examples to features: 337it [00:05, 20.81it/s]
# convert examples to features: 340it [00:06, 21.35it/s]
# convert examples to features: 343it [00:06, 23.01it/s]
# convert examples to features: 346it [00:06, 24.27it/s]
# convert examples to features: 349it [00:06, 25.33it/s]
# convert examples to features: 352it [00:06, 26.15it/s]
# convert examples to features: 355it [00:06, 26.86it/s]
# convert examples to features: 358it [00:06, 25.32it/s]
# convert examples to features: 361it [00:06, 23.12it/s]
# convert examples to features: 364it [00:07, 21.73it/s]
# convert examples to features: 367it [00:07, 20.86it/s]
# convert examples to features: 370it [00:07, 14.05it/s]
# convert examples to features: 372it [00:07, 10.08it/s]
# convert examples to features: 374it [00:08,  8.44it/s]
# convert examples to features: 376it [00:08,  7.54it/s]
# convert examples to features: 377it [00:08,  6.95it/s]
# convert examples to features: 378it [00:08,  6.62it/s]
# convert examples to features: 379it [00:09,  6.42it/s]
# convert examples to features: 380it [00:09,  6.23it/s]
# convert examples to features: 381it [00:09,  6.14it/s]
# convert examples to features: 382it [00:09,  6.08it/s]
# convert examples to features: 383it [00:09,  4.81it/s]
# convert examples to features: 384it [00:10,  4.15it/s]
# convert examples to features: 385it [00:10,  3.74it/s]
# convert examples to features: 386it [00:10,  3.56it/s]
# convert examples to features: 387it [00:11,  3.46it/s]
# convert examples to features: 388it [00:11,  3.37it/s]
# convert examples to features: 389it [00:11,  3.32it/s]
# convert examples to features: 390it [00:12,  3.28it/s]
# convert examples to features: 391it [00:12,  3.25it/s]
# convert examples to features: 392it [00:12,  3.22it/s]
# convert examples to features: 393it [00:13,  3.19it/s]
# convert examples to features: 394it [00:13,  3.17it/s]
# convert examples to features: 395it [00:13,  3.15it/s]
# convert examples to features: 396it [00:14,  3.14it/s]
# convert examples to features: 397it [00:14,  3.12it/s]
# convert examples to features: 398it [00:14,  3.11it/s]
# convert examples to features: 399it [00:15,  3.10it/s]
# convert examples to features: 400it [00:15,  3.10it/s]
# convert examples to features: 401it [00:15,  3.09it/s]
# convert examples to features: 402it [00:16,  3.09it/s]
# convert examples to features: 403it [00:16,  3.10it/s]
# convert examples to features: 404it [00:16,  3.10it/s]
# convert examples to features: 405it [00:16,  3.11it/s]
# convert examples to features: 406it [00:17,  3.12it/s]
# convert examples to features: 407it [00:17,  3.13it/s]
# convert examples to features: 408it [00:17,  3.13it/s]
# convert examples to features: 411it [00:18,  4.28it/s]
# convert examples to features: 414it [00:18,  5.75it/s]
# convert examples to features: 417it [00:18,  7.58it/s]
# convert examples to features: 420it [00:18,  9.49it/s]
# convert examples to features: 423it [00:18, 10.78it/s]
# convert examples to features: 425it [00:18, 11.79it/s]
# convert examples to features: 427it [00:18, 12.69it/s]
# convert examples to features: 429it [00:18, 13.44it/s]
# convert examples to features: 431it [00:19, 13.83it/s]
# convert examples to features: 433it [00:19, 14.26it/s]
# convert examples to features: 436it [00:19, 16.23it/s]
# convert examples to features: 440it [00:19, 19.09it/s]
# convert examples to features: 444it [00:19, 21.74it/s]
# convert examples to features: 452it [00:19, 27.58it/s]
# convert examples to features: 461it [00:19, 34.56it/s]
# convert examples to features: 469it [00:19, 41.34it/s]
# convert examples to features: 476it [00:20, 43.47it/s]
# convert examples to features: 482it [00:20, 36.05it/s]
# convert examples to features: 487it [00:20, 32.14it/s]
# convert examples to features: 492it [00:20, 29.94it/s]
# convert examples to features: 503it [00:20, 37.87it/s]
# convert examples to features: 509it [00:20, 42.23it/s]
# convert examples to features: 515it [00:20, 45.82it/s]
# convert examples to features: 521it [00:21, 32.60it/s]
# convert examples to features: 526it [00:22, 11.45it/s]
# convert examples to features: 530it [00:23,  7.90it/s]
# convert examples to features: 533it [00:23,  6.48it/s]
# convert examples to features: 535it [00:24,  5.73it/s]
# convert examples to features: 537it [00:24,  5.28it/s]
# convert examples to features: 547it [00:24,  7.38it/s]
# convert examples to features: 555it [00:25, 10.12it/s]
# convert examples to features: 564it [00:25, 22.29it/s]
# Epoch: 100%|██████████| 50/50 [2:00:29<00:00, 144.58s/it]
# convert examples to features: 564it [00:24, 22.70it/s]
# convert examples to features: 564it [00:24, 22.74it/s]
# convert examples to features: 564it [00:24, 22.80it/s]
# convert examples to features: 564it [00:24, 22.90it/s]
# convert examples to features: 564it [00:24, 22.82it/s]
# convert examples to features: 564it [00:24, 22.80it/s]
# convert examples to features: 564it [00:27, 20.77it/s]
# convert examples to features: 564it [00:24, 22.87it/s]
# convert examples to features: 564it [00:24, 22.79it/s]
# convert examples to features: 564it [00:24, 22.77it/s]
# convert examples to features: 564it [00:24, 22.87it/s]
# convert examples to features: 564it [00:24, 22.73it/s]
# convert examples to features: 564it [00:24, 22.84it/s]
# convert examples to features: 564it [00:24, 22.83it/s]
# convert examples to features: 564it [00:24, 22.62it/s]
# convert examples to features: 564it [00:24, 22.81it/s]
# convert examples to features: 564it [00:24, 22.64it/s]
# convert examples to features: 564it [00:24, 22.61it/s]
# convert examples to features: 564it [00:24, 22.64it/s]
# convert examples to features: 564it [00:24, 22.58it/s]
# convert examples to features: 564it [00:25, 22.46it/s]
# convert examples to features: 564it [00:25, 22.32it/s]
# convert examples to features: 564it [00:24, 22.80it/s]

# %% [markdown]
# ## Test

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
import warnings
warnings.filterwarnings('ignore')

def main():
    parser = argparse.ArgumentParser()

    # Required parameters
    parser.add_argument(
        "--data_dir",
        default="drive/My Drive/CODE/ViMMRC/dataset/race_ver_2",
        type=str,
        help="The input data dir. Should contain the .tsv files (or other data files) for the task.",
    )

    parser.add_argument(
        "--model_type",
        default="bert",
        type=str,
        help="Model type selected in the list: " + ", ".join(MODEL_CLASSES.keys()),
    )
    parser.add_argument(
        "--model_name_or_path",
        default=OUTPUT_DIR,
        type=str,
        help="Path to pre-trained model or shortcut name selected in the list: "
        + ", ".join(ALL_MODELS),
    )
    
    parser.add_argument(
        "--task_name",
        default="race",
        type=str,
        help="The name of the task to train selected in the list: " + ", ".join(processors.keys()),
    )
    parser.add_argument(
        "--para_type",
        default="per_choice",
        type=str,
        choices=["per_choice", "concat_choices", "ignore"],
        help="Paragraph building strategy for ARC (default: %(default)s)",
    )
    parser.add_argument(
        "--output_predictions",
        default=True,
        type=bool,
        help="Whether to export the predictions from the eval step.",
    )
    parser.add_argument(
        "--output_dir",
        default=OUTPUT_DIR,
        type=str,
        help="The output directory where the model predictions and checkpoints will be written.",
    )
    parser.add_argument(
        "--freeze_embeddings", default=False, action="store_true", help="Whether to freeze the embeeding layer.",
    )
    parser.add_argument(
        "--freeze_layers", nargs="*", help="Whether to freeze the embeeding layer.",
    )

    # Other parameters
    parser.add_argument(
        "--tb_log_dir",
        default="",
        type=str,
        help="Tensorboard log dir for the current experiment",
    )

    parser.add_argument(
        "--config_name",
        default="",
        type=str,
        help="Pretrained config name or path if not the same as model_name",
    )
    parser.add_argument(
        "--tokenizer_name",
        default="",
        type=str,
        help="Pretrained tokenizer name or path if not the same as model_name",
    )
    parser.add_argument(
        "--cache_dir",
        default=OUTPUT_DIR,
        type=str,
        help="Where do you want to store the pre-trained models downloaded from s3",
    )
    parser.add_argument(
        "--max_seq_length",
        default=300,
        type=int,
        help="The maximum total input sequence length after tokenization. Sequences longer "
        "than this will be truncated, sequences shorter will be padded.",
    )
    parser.add_argument("--do_train", default = False, action="store_true", help="Whether to run training.")
    parser.add_argument(
        "--do_eval", default = True, action="store_true", help="Whether to run eval on the dev set."
    )
    parser.add_argument(
        "--do_test", default = True, action="store_true", help="Whether to run test on the test set"
    )
    parser.add_argument(
        "--evaluate_during_training",
        action="store_true",
        default = True,
        help="Run evaluation during training at each logging step.",
    )
    parser.add_argument(
        "--do_lower_case",
        action="store_true",
        default = False,
        help="Set this flag if you are using an uncased model.",
    )

    parser.add_argument(
        "--per_gpu_train_batch_size",
        default=4,
        type=int,
        help="Batch size per GPU/CPU for training.",
    )
    parser.add_argument(
        "--per_gpu_eval_batch_size",
        default=1,
        type=int,
        help="Batch size per GPU/CPU for evaluation.",
    )
    parser.add_argument(
        "--gradient_accumulation_steps",
        type=int,
        default=8,
        help="Number of updates steps to accumulate before performing a backward/update pass.",
    )
    parser.add_argument(
        "--learning_rate", default=1e-5, type=float, help="The initial learning rate for Adam."
    )
    parser.add_argument(
        "--weight_decay", default=0.0, type=float, help="Weight deay if we apply some."
    )
    parser.add_argument(
        "--adam_epsilon", default=1e-8, type=float, help="Epsilon for Adam optimizer."
    )
    parser.add_argument("--max_grad_norm", default=1.0, type=float, help="Max gradient norm.")
    parser.add_argument(
        "--num_train_epochs",
        default=20,
        type=float,
        help="Total number of training epochs to perform.",
    )
    parser.add_argument(
        "--max_steps",
        default=-1,
        type=int,
        help="If > 0: set total number of training steps to perform. Override num_train_epochs.",
    )
    parser.add_argument(
        "--warmup_proportion", default=0.1, type=float, help="Linear warmup over warmup_proportion."
    )

    parser.add_argument("--logging_steps", type=int, default=500, help="Log every X updates steps.")
    parser.add_argument(
        "--save_steps", type=int, default=500, help="Save checkpoint every X updates steps."
    )
    parser.add_argument(
        "--eval_all_checkpoints",
        default = True,
        action="store_true",
        help="Evaluate all checkpoints starting with the same prefix as model_name ending and ending with step number",
    )
    parser.add_argument("--no_cuda", default = False, action="store_true", help="Avoid using CUDA when available")
    parser.add_argument(
        "--overwrite_output_dir",
        default = True,
        action="store_true",
        help="Overwrite the content of the output directory",
    )
    parser.add_argument(
        "--overwrite_cache",
        default = True,
        action="store_true",
        help="Overwrite the cached training and evaluation sets",
    )
    parser.add_argument("--seed", type=int, default=42, help="random seed for initialization")

    parser.add_argument(
        "--fp16",
        action="store_true",
        help="Whether to use 16-bit (mixed) precision (through NVIDIA apex) instead of 32-bit",
    )
    parser.add_argument(
        "--fp16_opt_level",
        type=str,
        default="O1",
        help="For fp16: Apex AMP optimization level selected in ['O0', 'O1', 'O2', and 'O3']."
        "See details at https://nvidia.github.io/apex/amp.html",
    )
    parser.add_argument(
        "--local_rank", type=int, default=-1, help="For distributed training: local_rank"
    )
    parser.add_argument("--server_ip", type=str, default="", help="For distant debugging.")
    parser.add_argument("--server_port", type=str, default="", help="For distant debugging.")

    parser.add_argument('-f')

    args = parser.parse_args()

    options_print = ""
    logger.info("Arg Options - input:")
    for arg in vars(args):
        options_print += "opt: %s=%s\r\n" % (arg, getattr(args, arg))
    logger.info(options_print)

    if (
        os.path.exists(args.output_dir)
        and os.listdir(args.output_dir)
        and args.do_train
        and not args.overwrite_output_dir
    ):
        raise ValueError(
            "Output directory ({}) already exists and is not empty. Use --overwrite_output_dir to overcome.".format(
                args.output_dir
            )
        )

    # Setup distant debugging if needed
    if args.server_ip and args.server_port:
        # Distant debugging - see https://code.visualstudio.com/docs/python/debugging#_attach-to-a-local-script
        import ptvsd

        print("Waiting for debugger attach")
        ptvsd.enable_attach(address=(args.server_ip, args.server_port), redirect_output=True)
        ptvsd.wait_for_attach()

    # Setup CUDA, GPU & distributed training
    if args.local_rank == -1 or args.no_cuda:
        device = torch.device("cuda" if torch.cuda.is_available() and not args.no_cuda else "cpu")
        args.n_gpu = 0 if args.no_cuda else torch.cuda.device_count()
    else:  # Initializes the distributed backend which will take care of sychronizing nodes/GPUs
        torch.cuda.set_device(args.local_rank)
        device = torch.device("cuda", args.local_rank)
        torch.distributed.init_process_group(backend="nccl")
        args.n_gpu = 1
    args.device = device

    # Setup logging
    logging.basicConfig(
        format="%(asctime)s - %(levelname)s - %(name)s -   %(message)s",
        datefmt="%m/%d/%Y %H:%M:%S",
        level=logging.INFO if args.local_rank in [-1, 0] else logging.WARN,
    )
    logger.warning(
        "Process rank: %s, device: %s, n_gpu: %s, distributed training: %s, 16-bits training: %s",
        args.local_rank,
        device,
        args.n_gpu,
        bool(args.local_rank != -1),
        args.fp16,
    )

    # Set seed
    set_seed(args)

    # Prepare GLUE task
    args.task_name = args.task_name.lower()
    if args.task_name not in processors:
        raise ValueError("Task not found: %s" % (args.task_name))
    processor = (
        processors[args.task_name]()
        if args.task_name not in ["arc", "exams",]
        else processors[args.task_name](para_type=args.para_type)
    )
    label_list = processor.get_labels()
    num_labels = len(label_list)

    # Load pretrained model and tokenizer
    if args.local_rank not in [-1, 0]:
        torch.distributed.barrier()  # Make sure only the first process in distributed training will download model & vocab

    args.model_type = args.model_type.lower()
    config_class, model_class, tokenizer_class = MODEL_CLASSES[args.model_type]
    config = config_class.from_pretrained(
        args.config_name if args.config_name else args.model_name_or_path,
        num_labels=num_labels,
        finetuning_task=args.task_name,
        cache_dir=args.cache_dir if args.cache_dir else None,
    )
    tokenizer = tokenizer_class.from_pretrained(
        args.tokenizer_name if args.tokenizer_name else args.model_name_or_path,
        do_lower_case=args.do_lower_case,
        cache_dir=args.cache_dir if args.cache_dir else None,
    )
    model = model_class.from_pretrained(
        args.model_name_or_path,
        from_tf=bool(".ckpt" in args.model_name_or_path),
        config=config,
        cache_dir=args.cache_dir if args.cache_dir else None,
    )

    if args.local_rank == 0:
        torch.distributed.barrier()  # Make sure only the first process in distributed training will download model & vocab

    options_print = ""
    logging.info("Arg Options:")
    for arg in vars(args):
        options_print += "opt: %s=%s\r\n" % (arg, getattr(args, arg))
    logging.info(options_print)

    model.to(args.device)

    def get_model_base_obj(model, model_type):
        if model_type == "bert":
            return model.bert
        elif model_type == "xlm-roberta" or model_type == "roberta":
            return model.roberta
        elif model_type == "xlm-roberta":
            return model.distilbert
        else:
            raise ValueError("model_type='{0}' is not supported!")

    if args.freeze_embeddings:
        for param in list(get_model_base_obj(model, args.model_type).embeddings.parameters()):
            param.requires_grad = False
        logger.info("Froze Embedding Layer")

    # freeze_layers is a string "1,2,3" representing layer number
    if args.freeze_layers:
        layer_indexes = [int(x) for x in args.freeze_layers]
        for layer_idx in layer_indexes:
            for param in list(
                get_model_base_obj(model, args.model_type).encoder.layer[layer_idx].parameters()
            ):
                param.requires_grad = False
            logger.info("Froze Layer: %s", layer_idx)

    logger.info("Training/evaluation parameters %s", args)
    best_steps = 0

    # Training
    if args.do_train:
        train_dataset = load_and_cache_examples(args, args.task_name, tokenizer, evaluate=False)
        global_step, tr_loss, best_steps = train(args, train_dataset, model, tokenizer)
        logger.info(" global_step = %s, average loss = %s", global_step, tr_loss)

    # Saving best-practices: if you use defaults names for the model, you can reload it using from_pretrained()
    if args.do_train and (args.local_rank == -1 or torch.distributed.get_rank() == 0):
        # Create output directory if needed
        if not os.path.exists(args.output_dir) and args.local_rank in [-1, 0]:
            os.makedirs(args.output_dir)

        logger.info("Saving model checkpoint to %s", args.output_dir)
        # Save a trained model, configuration and tokenizer using `save_pretrained()`.
        # They can then be reloaded using `from_pretrained()`
        model_to_save = (
            model.module if hasattr(model, "module") else model
        )  # Take care of distributed/parallel training
        model_to_save.save_pretrained(args.output_dir)
        tokenizer.save_pretrained(args.output_dir)

        # Good practice: save your training arguments together with the trained model
        torch.save(args, os.path.join(args.output_dir, "training_args.bin"))

        # Load a trained model and vocabulary that you have fine-tuned
        model = model_class.from_pretrained(args.output_dir)
        tokenizer = tokenizer_class.from_pretrained(args.output_dir)
        model.to(args.device)

    # Evaluation
    results = {}
    if args.do_eval and args.local_rank in [-1, 0]:
        if not args.do_train:
            args.output_dir = args.model_name_or_path
        checkpoints = [args.output_dir]
        if args.eval_all_checkpoints:
            checkpoints = list(
                os.path.dirname(c)
                for c in sorted(glob.glob(args.output_dir + "/**/" + WEIGHTS_NAME, recursive=True))
            )
            logging.getLogger("transformers.modeling_utils").setLevel(
                logging.WARN
            )  # Reduce logging
        logger.info("Evaluate the following checkpoints: %s", checkpoints)
        for checkpoint in checkpoints:
            global_step = checkpoint.split("-")[-1] if len(checkpoints) > 1 else ""
            prefix = checkpoint.split("/")[-1] if checkpoint.find("checkpoint") != -1 else ""

            model = model_class.from_pretrained(checkpoint)
            model.to(args.device)
            result = evaluate(args, model, tokenizer, prefix=prefix)
            result = dict((k + "_{}".format(global_step), v) for k, v in result.items())
            results.update(result)

    if args.do_test and args.local_rank in [-1, 0]:
        checkpoints = [args.model_name_or_path]
        logger.info("Evaluate the following checkpoints: %s", checkpoints)
        for checkpoint in checkpoints:
            global_step = checkpoint.split("-")[-1] if len(checkpoints) > 1 else ""
            prefix = checkpoint.split("/")[-1] if checkpoint.find("checkpoint") != -1 else ""

            model = model_class.from_pretrained(checkpoint)
            model.to(args.device)
            result = evaluate(args, model, tokenizer, prefix=prefix, test=True)
            result = dict((k + "_{}".format(global_step), v) for k, v in result.items())
            results.update(result)
    if best_steps:
        logger.info("best steps of eval acc is the following checkpoints: %s", best_steps)
    return results

import logging
logging.disable(logging.INFO) # disable INFO and DEBUG logging everywhere
# or 
logging.disable(logging.WARNING) # disable WARNING, INFO and DEBUG logging everywhere

if __name__ == "__main__":
    main()
# Out:
# convert examples to features: 564it [00:23, 24.01it/s]
# convert examples to features: 564it [00:23, 24.02it/s]
# convert examples to features: 564it [00:23, 24.03it/s]
# convert examples to features: 564it [00:23, 24.13it/s]
# convert examples to features: 564it [00:23, 23.89it/s]
# convert examples to features: 564it [00:23, 24.11it/s]
# convert examples to features: 564it [00:23, 24.05it/s]
# convert examples to features: 564it [00:23, 23.89it/s]
# convert examples to features: 564it [00:23, 23.99it/s]
# convert examples to features: 564it [00:23, 24.02it/s]
# convert examples to features: 564it [00:23, 24.03it/s]
# convert examples to features: 564it [00:23, 24.01it/s]
# convert examples to features: 564it [00:23, 23.98it/s]
# convert examples to features: 564it [00:23, 23.88it/s]
# convert examples to features: 564it [00:23, 23.75it/s]
# convert examples to features: 564it [00:23, 23.82it/s]
# convert examples to features: 564it [00:23, 23.76it/s]
# convert examples to features: 564it [00:23, 23.78it/s]
# convert examples to features: 564it [00:23, 23.86it/s]
# convert examples to features: 564it [00:23, 23.82it/s]
# convert examples to features: 564it [00:23, 23.89it/s]
# convert examples to features: 564it [00:23, 23.86it/s]
# convert examples to features: 564it [00:23, 23.86it/s]
# convert examples to features: 1109it [00:46, 23.81it/s]
